# %%
import os, sys
import pandas as pd
import json
import numpy as np

# %%
# Pandas configuration to show Dataframes
pd.set_option("display.max_columns", None)     # Show all columns

# %%
ea_papers = 'data/enriched_aggregated_papers.csv'
oa_papers = 'data/original_aggregated_papers.csv'

# %%
ea_papers_df = pd.read_table(ea_papers, encoding='utf-8')
oa_papers_df = pd.read_table(oa_papers, encoding='utf-8')

# %%
ordered_articles_ea = ea_papers_df.sort_values(by='Article Title')['Article Title'].tolist()

# %%
ordered_articles_oa = oa_papers_df.sort_values(by='Article Title')['Article Title'].tolist()

# %%
if ordered_articles_ea == ordered_articles_oa:
    print("Both tables contain the same articles")
# Out:
# Both tables contain the same articles

# %%
ea_papers_df
# Out:
#                                           Article Title     source  \
# 0     0s and 1s in marine molecular research: a regi...        MED
# 1     1,4-Disubstituted 1H-1,2,3-Triazole Containing...        MED
# 2     10th Anniversary of the European Association f...        NaN
# 3     10th European Conference on Rare Diseases & Or...        MED
# 4     1H, 13C and 15N assignment of the human mitoch...        NaN
# ...                                                 ...        ...
# 3392  The Dutch Techcentre for Life Sciences: Enabli...        PPR
# 3393  The ELIXIR Biodiversity Community: Understandi...        PPR
# 3394                The ELIXIR channel in F1000Research        PPR
# 3395  The need for standardisation in life science r...  MED | PPR
# 3396  Transformer-based tool recommendation system i...        PPR
#
#             pmid       pmcid                          doi_df1  \
# 0     34405237.0  PMC8371273      10.1093/gigascience/giab053
# 1     30972322.0  PMC6443886         10.3389/fchem.2019.00155
# 2            NaN         NaN                              NaN
# 3     33168048.0  PMC7649705       10.1186/s13023-020-01550-1
# 4            NaN         NaN                              NaN
# ...          ...         ...                              ...
# 3392         NaN         NaN    10.12688/f1000research.6009.2
# 3393         NaN         NaN  10.12688/f1000research.133724.2
# 3394         NaN         NaN    10.12688/f1000research.7587.2
# 3395  33604028.0  PMC7863991   10.12688/f1000research.27500.2
# 3396         NaN         NaN        10.1101/2022.12.16.520746
#
#                                                   title  \
# 0     0s and 1s in marine molecular research: a regi...
# 1     1,4-Disubstituted 1H-1,2,3-Triazole Containing...
# 2                                                   NaN
# 3     10th European Conference on Rare Diseases & Or...
# 4                                                   NaN
# ...                                                 ...
# 3392  The Dutch Techcentre for Life Sciences: Enabli...
# 3393  The ELIXIR Biodiversity Community: Understandi...
# 3394                The ELIXIR channel in F1000Research
# 3395  The need for standardisation in life science r...
# 3396  Transformer-based tool recommendation system i...
#
#                                            authorString  \
# 0     Zafeiropoulos H, Gioti A, Ninidakis S, Potirak...
# 1     Schröder DC, Kracker O, Fröhr T, Góra J, Jewgi...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3392  Eijssen L, Evelo CT, Kok R, Mons B, Hooft RW, ...
# 3393  Waterhouse RM, Adam-Blondon A, Balech B, Barta...
# 3394  Blomberg N, Oliveira A, Mons B, Persson B, Jon...
# 3395  Hollmann S, Kremer A, Baebler Š, Trefois C, Gr...
# 3396                    Kumar A, Grüning B, Backofen R.
#
#      first_author_firstName first_author_lastName last_author_firstName  \
# 0                     Haris         Zafeiropoulos             Evangelos
# 1                   David C              Schröder               Norbert
# 2                       NaN                   NaN                   NaN
# 3                       NaN                   NaN                   NaN
# 4                       NaN                   NaN                   NaN
# ...                     ...                   ...                   ...
# 3392                   Lars               Eijssen                   NaN
# 3393                 Robert            Waterhouse                  Toni
# 3394                 Niklas              Blomberg                  Inge
# 3395                Susanne              Hollmann              Domenica
# 3396                   Anup                 Kumar                  Rolf
#
#      last_author_lastName                                       abstractText  \
# 0                 Pafilis  High-performance computing (HPC) systems have ...
# 1                  Sewald  Peptidotriazolamers are hybrid foldamers with ...
# 2                     NaN                                                NaN
# 3                     NaN                                                NaN
# 4                     NaN                                                NaN
# ...                   ...                                                ...
# 3392                  NaN  We describe the Data programme of the Dutch Te...
# 3393             Gabaldón  Biodiversity loss is now recognised as one of ...
# 3394             Jonassen  ELIXIR, the European life science infrastructu...
# 3395               D'Elia  Today, academic researchers benefit from the c...
# 3396             Backofen  Galaxy is a web-based open-source platform for...
#
#      printPublicationDate                  journal_title_df1  \
# 0              2021-08-01                        GigaScience
# 1              2019-01-01             Frontiers in chemistry
# 2                     NaN                                NaN
# 3              2020-11-01  Orphanet journal of rare diseases
# 4                     NaN                                NaN
# ...                   ...                                ...
# 3392                  NaN                                NaN
# 3393                  NaN                                NaN
# 3394                  NaN                                NaN
# 3395           2020-01-01                      F1000Research
# 3396                  NaN                                NaN
#
#                                             affiliation  \
# 0     Hellenic Centre for Marine Research, Institute...
# 1     Organic and Bioorganic Chemistry, Department o...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3392                                                NaN
# 3393                                                NaN
# 3394                                                NaN
# 3395  Faculty of Science, University of Potsdam, Pot...
# 3396                                                NaN
#
#                                                keywords  \
# 0     Biodiversity, Biotechnology, Aquaculture, High...
# 1     1, 2, Foldamer, Molecular Dynamic Simulations,...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3392                                                NaN
# 3393                                                NaN
# 3394                                                NaN
# 3395  Education, Open Access, Quality Management, St...
# 3396                                                NaN
#
#                                            meshHeadings  \
# 0     Marine Biology, Biotechnology, Aquaculture, Co...
# 1                                                   NaN
# 2                                                   NaN
# 3     Humans, Rare Diseases, Drug Approval, Orphan D...
# 4                                                   NaN
# ...                                                 ...
# 3392                                                NaN
# 3393                                                NaN
# 3394                                                NaN
# 3395  Trust, International Cooperation, Quality of L...
# 3396                                                NaN
#
#                                               mod_title         Year  \
# 0     0SAND1SINMARINEMOLECULARRESEARCH:AREGIONALHPCP...         2021
# 1     1,4-DISUBSTITUTED1H-1,2,3-TRIAZOLECONTAININGPE...         2019
# 2     10THANNIVERSARYOFTHEEUROPEANASSOCIATIONFORPRED...         2020
# 3     10THEUROPEANCONFERENCEONRAREDISEASES&ORPHANPRO...         2020
# 4     1H,13CAND15NASSIGNMENTOFTHEHUMANMITOCHONDRIALP...         2022
# ...                                                 ...          ...
# 3392  THEDUTCHTECHCENTREFORLIFESCIENCES:ENABLINGDATA...  2015 | 2016
# 3393  THEELIXIRBIODIVERSITYCOMMUNITY:UNDERSTANDINGSH...  2024 | 2023
# 3394                    THEELIXIRCHANNELINF1000RESEARCH  2015 | 2016
# 3395  THENEEDFORSTANDARDISATIONINLIFESCIENCERESEARCH...         2020
# 3396  TRANSFORMER-BASEDTOOLRECOMMENDATIONSYSTEMINGALAXY  2023 | 2022
#
#                       journal_title_df2  \
# 0                           GigaScience
# 1                Frontiers in chemistry
# 2                      The EPMA journal
# 3     Orphanet journal of rare diseases
# 4          Biomolecular NMR assignments
# ...                                 ...
# 3392                                NaN
# 3393                                NaN
# 3394                                NaN
# 3395                      F1000Research
# 3396                 BMC bioinformatics
#
#                                                 doi_df2     Source  empty  \
# 0                           10.1093/gigascience/giab053        MED    NaN
# 1                                                   NaN        MED    NaN
# 2                            10.1007/s13167-020-00206-1        MED    NaN
# 3                            10.1186/s13023-020-01550-1        MED    NaN
# 4                            10.1007/s12104-022-10113-3        MED    NaN
# ...                                                 ...        ...    ...
# 3392                      10.12688/f1000research.6009.2        PPR    NaN
# 3393  10.12688/f1000research.133724.2 | 10.12688/f10...        PPR    NaN
# 3394                      10.12688/f1000research.7587.2        PPR    NaN
# 3395                     10.12688/f1000research.27500.1        MED    NaN
# 3396                          10.1101/2022.12.16.520746  PMC | PPR    NaN
#
#                             final_doi
# 0         10.1093/gigascience/giab053
# 1            10.3389/fchem.2019.00155
# 2          10.1007/s13167-020-00206-1
# 3          10.1186/s13023-020-01550-1
# 4          10.1007/s12104-022-10113-3
# ...                               ...
# 3392    10.12688/f1000research.6009.2
# 3393  10.12688/f1000research.133724.2
# 3394    10.12688/f1000research.7587.2
# 3395   10.12688/f1000research.27500.2
# 3396        10.1101/2022.12.16.520746
#
# [3397 rows x 24 columns]

# %% [markdown]
# We will work then with the enriched table as it contains information about the authors.

# %%
ea_papers_df.columns
# Out:
# Index(['Article Title', 'source', 'pmid', 'pmcid', 'doi_df1', 'title',
#        'authorString', 'first_author_firstName', 'first_author_lastName',
#        'last_author_firstName', 'last_author_lastName', 'abstractText',
#        'printPublicationDate', 'journal_title_df1', 'affiliation', 'keywords',
#        'meshHeadings', 'mod_title', 'Year', 'journal_title_df2', 'doi_df2',
#        'Source', 'empty', 'final_doi'],
#       dtype='object')

# %%
# check for NaN or duplicated article titles
print(f"Amount of NaN article titles: {len(ea_papers_df[ea_papers_df['Article Title'].isna()])}")
print(f"Amount of duplicated article titles: {len(ea_papers_df[ea_papers_df['Article Title'].duplicated()])}")
# Out:
# Amount of NaN article titles: 0
# Amount of duplicated article titles: 0

# %%
# check for missing PMCIDs (after checking the code of GenderTracker)
print(f"Amount of articles with unknown PMCIDs: {len(ea_papers_df[ea_papers_df['pmcid'].isna()])}")
# Out:
# Amount of articles with unknown PMCIDs: 651

# %% [markdown]
# That's not very encouraging - the GenderTracker script uses PMCID as the main key to identify the article. However, we will test by putting the article title instead in order for us to not miss so much data in our gender predictions.

# %%
ea_papers_df['first_author'] = ea_papers_df['first_author_firstName'] + ' ' + ea_papers_df['first_author_lastName']
ea_papers_df['last_author'] = ea_papers_df['last_author_firstName'] + ' ' + ea_papers_df['last_author_lastName']

# %%
articles_full_authors = ea_papers_df[
    ea_papers_df['first_author_firstName'].notna() &
    ea_papers_df['first_author_lastName'].notna() &
    ea_papers_df['last_author_firstName'].notna() &
    ea_papers_df['last_author_lastName'].notna()
]

articles_first_authors_all = ea_papers_df[
    ea_papers_df['first_author_firstName'].notna() &
    ea_papers_df['first_author_lastName'].notna() &
    ea_papers_df['last_author_firstName'].isna() &
    ea_papers_df['last_author_lastName'].isna()
]

articles_first_authors_name = ea_papers_df[
    ea_papers_df['first_author_firstName'].notna() &
    ea_papers_df['first_author_lastName'].isna() &
    ea_papers_df['last_author_firstName'].isna() &
    ea_papers_df['last_author_lastName'].isna()
]

articles_first_authors_surname = ea_papers_df[
    ea_papers_df['first_author_firstName'].isna() &
    ea_papers_df['first_author_lastName'].notna() &
    ea_papers_df['last_author_firstName'].isna() &
    ea_papers_df['last_author_lastName'].isna()
]

articles_last_authors_all = ea_papers_df[
    ea_papers_df['first_author_firstName'].isna() &
    ea_papers_df['first_author_lastName'].isna() &
    ea_papers_df['last_author_firstName'].notna() &
    ea_papers_df['last_author_lastName'].notna()
]

articles_last_authors_name = ea_papers_df[
    ea_papers_df['first_author_firstName'].isna() &
    ea_papers_df['first_author_lastName'].isna() &
    ea_papers_df['last_author_firstName'].notna() &
    ea_papers_df['last_author_lastName'].isna()
]

articles_last_authors_surname = ea_papers_df[
    ea_papers_df['first_author_firstName'].isna() &
    ea_papers_df['first_author_lastName'].isna() &
    ea_papers_df['last_author_firstName'].isna() &
    ea_papers_df['last_author_lastName'].notna()
]

articles_none_authors = ea_papers_df[
    ea_papers_df['first_author_firstName'].isna() &
    ea_papers_df['first_author_lastName'].isna() &
    ea_papers_df['last_author_firstName'].isna() &
    ea_papers_df['last_author_lastName'].isna()
]

# %%
print(f"Papers with full author info: {len(articles_full_authors)}")
print(f"Papers with full first author info: {len(articles_first_authors_all)}")
print(f"Papers with name only first author info: {len(articles_first_authors_name)}")
print(f"Papers with surname only first author info: {len(articles_first_authors_surname)}")
print(f"Papers with full last author info: {len(articles_last_authors_all)}")
print(f"Papers with name only last author info: {len(articles_last_authors_name)}")
print(f"Papers with surname only last author info: {len(articles_last_authors_surname)}")
print(f"Papers with none author info: {len(articles_none_authors)}")
# Out:
# Papers with full author info: 3054
# Papers with full first author info: 109
# Papers with name only first author info: 0
# Papers with surname only first author info: 1
# Papers with full last author info: 2
# Papers with name only last author info: 0
# Papers with surname only last author info: 0
# Papers with none author info: 225

# %% [markdown]
# Most papers have information about all the authors. Let's first work with these ones as input to **GenderTracker** and see what it predicts.

# %% [markdown]
# 1) The first step is to convert the CSV to JSON format required by GenderTracker:

# %%
def csv_to_json_format(input_table, output_json: str) -> None:
    
    # Read the CSV file
    if type(input_table)==str: 
        df = pd.read_csv(input_table)
    elif isinstance(input_table, pd.DataFrame):
        df = input_table

    # Prepare the list for JSON data
    json_data = []

    # Iterate over each row to create the desired JSON structure
    for _, row in df.iterrows():
        # Extract relevant fields
        pmcid = row['Article Title']
        first_author_first_name = row['first_author_firstName']
        first_author_last_name = row['first_author_lastName']
        last_author_first_name = row['last_author_firstName']
        last_author_last_name = row['last_author_lastName']

        # Construct the full names of authors
        authors = []
        if pd.notna(first_author_first_name) and pd.notna(first_author_last_name):
            first_author = f"{first_author_first_name} {first_author_last_name}"
            authors.append(first_author)
            authors.append(first_author_first_name)
            authors.append(first_author_last_name)
        else:
            authors.append("NaN")
            authors.append("NaN")
            authors.append("NaN")
            
        if pd.notna(last_author_first_name) and pd.notna(last_author_last_name):
            last_author = f"{last_author_first_name} {last_author_last_name}"
            authors.append(last_author)
            authors.append(last_author_first_name)
            authors.append(last_author_last_name)
        else:
            authors.append("NaN")
            authors.append("NaN")
            authors.append("NaN")

        # Format authors list as JSON string
        authors_json_str = json.dumps(authors)

        # Append the data in the required format
        json_data.append({
            "pmcid": pmcid,
            "authors": authors_json_str
        })

    # Write to output JSON file with proper encoding
    with open(output_json, 'w', encoding='utf-8') as json_file:
        json.dump(json_data, json_file, ensure_ascii=False, indent=4)

# %%
csv_to_json_format(input_table = ea_papers_df, output_json = 'ea_papers_author_data.json')

# %%
with open('ea_papers_author_data.json', 'r', encoding='utf-8') as jf:
    ea_papers_author_data = json.load(jf)

# %%
len(ea_papers_author_data) # matches the length of our previous filters
# Out:
# 3054

# %%
ea_papers_author_data
# Out:
# [{'pmcid': '0s and 1s in marine molecular research: a regional HPC perspective.',
#   'authors': '["Haris Zafeiropoulos", "Haris", "Zafeiropoulos", "Evangelos Pafilis", "Evangelos", "Pafilis"]'},
#  {'pmcid': '1,4-Disubstituted 1H-1,2,3-Triazole Containing Peptidotriazolamers: A New Class of Peptidomimetics With Interesting Foldamer Properties.',
#   'authors': '["David C Schr\\u00f6der", "David C", "Schr\\u00f6der", "Norbert Sewald", "Norbert", "Sewald"]'},
#  {'pmcid': '20 years of the SMART protein domain annotation resource.',
#   'authors': '["Ivica Letunic", "Ivica", "Letunic", "Peer Bork", "Peer", "Bork"]'},
#  {'pmcid': '2022 Outstanding Contributions to ISCB Award: Reinhard Schneider.',
#   'authors': '["Christina Fogg", "Christina", "Fogg", "Martin Vingron", "Martin", "Vingron"]'},
#  {'pmcid': '25 years of basic and translational science in EP Europace: novel insights into arrhythmia mechanisms and therapeutic strategies.',
#   'authors': '["Carol Ann Remme", "Carol Ann", "Remme", "Katja E Odening", "Katja E", "Odening"]'},
#  {'pmcid': '2DProts: Database of Family-Wide Protein Secondary Structure Diagrams.',
#   'authors': '["Ivana Huta\\u0159ov\\u00e1 Va\\u0159ekov\\u00e1", "Ivana", "Huta\\u0159ov\\u00e1 Va\\u0159ekov\\u00e1", "Karel Berka", "Karel", "Berka"]'},
#  {'pmcid': '3D-Beacons: Decreasing the gap between protein sequences and structures through a federated network of protein structure data resources',
#   'authors': '["Mihaly Varadi", "Mihaly", "Varadi", "Sameer Velankar", "Sameer", "Velankar"]'},
#  {'pmcid': '3D-Beacons: decreasing the gap between protein sequences and structures through a federated network of protein structure data resources.',
#   'authors': '["Mihaly Varadi", "Mihaly", "Varadi", "Sameer Velankar", "Sameer", "Velankar"]'},
#  {'pmcid': '3DBIONOTES v2.0: a web server for the automatic annotation of macromolecular structures.',
#   'authors': '["Joan Segura", "Joan", "Segura", "J M Carazo", "J M", "Carazo"]'},
#  {'pmcid': '3DBIONOTES v3.0: Crossing molecular and structural biology data with genomic variations.',
#   'authors': '["Joan Segura", "Joan", "Segura", "J M Carazo", "J M", "Carazo"]'},
#  {'pmcid': '3DBIONOTES: A unified, enriched and interactive view of macromolecular information.',
#   'authors': '["D Tabas-Madrid", "D", "Tabas-Madrid", "J M Carazo", "J M", "Carazo"]'},
#  {'pmcid': '3DBionotes COVID-19 Edition.',
#   'authors': '["Jose Ramon Macias", "Jose Ramon", "Macias", "Jose Maria Carazo", "Jose Maria", "Carazo"]'},
#  {'pmcid': '3DCONS-DB: A Database of Position-Specific Scoring Matrices in Protein Structures.',
#   'authors': '["Ruben Sanchez-Garcia", "Ruben", "Sanchez-Garcia", "Joan Segura", "Joan", "Segura"]'},
#  {'pmcid': '3DIANA: 3D Domain Interaction Analysis: A Toolbox for Quaternary Structure Modeling.',
#   'authors': '["Joan Segura", "Joan", "Segura", "Jose Maria Carazo", "Jose Maria", "Carazo"]'},
#  {'pmcid': '3DPatch: fast 3D structure visualization with residue conservation.',
#   'authors': '["David Jakubec", "David", "Jakubec", "Robert D Finn", "Robert D", "Finn"]'},
#  {'pmcid': 'A 1 bp deletion in HACE1 causes ataxia in Norwegian elkhound, black.',
#   'authors': '["Kim K L Bellamy", "Kim K L", "Bellamy", "Frode Lingaas", "Frode", "Lingaas"]'},
#  {'pmcid': 'A 3D cellular context for the macromolecular world.',
#   'authors': '["Ardan Patwardhan", "Ardan", "Patwardhan", "Gerard J Kleywegt", "Gerard J", "Kleywegt"]'},
#  {'pmcid': 'A Biobanking System for Diagnostic Images: Architecture Development, COVID-19-Related Use Cases, and Performance Evaluation.',
#   'authors': '["Giuseppina Esposito", "Giuseppina", "Esposito", "Antonio Pescap\\u00e8", "Antonio", "Pescap\\u00e8"]'},
#  {'pmcid': "A Boron-Containing Compound Acting on Multiple Targets Against Alzheimer's Disease. Insights from Ab Initio and Molecular Dynamics Simulations.",
#   'authors': '["Alessandra G Ritacca", "Alessandra G", "Ritacca", "Emilia Sicilia", "Emilia", "Sicilia"]'},
#  {'pmcid': 'A Census and Categorization Method of Epitranscriptomic Marks.',
#   'authors': '["Julia Mathlin", "Julia", "Mathlin", "Teresa Colombo", "Teresa", "Colombo"]'},
#  {'pmcid': 'A Chromosome-Level Reference Genome for the Black-Legged Kittiwake (Rissa tridactyla), a Declining Circumpolar Seabird.',
#   'authors': '["Marcella Sozzoni", "Marcella", "Sozzoni", "Diego Rubolini", "Diego", "Rubolini"]'},
#  {'pmcid': 'A Community-Driven, Openly Accessible Molecular Pathway Integrating Knowledge on Malignant Pleural Mesothelioma.',
#   'authors': '["Marvin Martens", "Marvin", "Martens", "Ferdinando Cerciello", "Ferdinando", "Cerciello"]'},
#  {'pmcid': 'A Comparison of Bonded and Nonbonded Zinc(II) Force Fields with NMR Data.',
#   'authors': '["Milana Bazayeva", "Milana", "Bazayeva", "Antonio Rosato", "Antonio", "Rosato"]'},
#  {'pmcid': 'A Comprehensive Analysis of 21 Actionable Pharmacogenes in the Spanish Population: From Genetic Characterisation to Clinical Impact.',
#   'authors': '["Rocio Nunez-Torres", "Rocio", "Nunez-Torres", "Anna Gonzalez-Neira", "Anna", "Gonzalez-Neira"]'},
#  {'pmcid': 'A Comprehensive Overview of the Genes and Functions Required for Lettuce Infection by the Hemibiotrophic Phytopathogen Xanthomonas hortorum pv. vitians.',
#   'authors': '["Lucas Morini\\u00e8re", "Lucas", "Morini\\u00e8re", "Franck Bertolla", "Franck", "Bertolla"]'},
#  {'pmcid': 'A Computational Approach to Elucidate the Interactions of Chemicals From Artemisia annua Targeted Toward SARS-CoV-2 Main Protease Inhibition for COVID-19 Treatment.',
#   'authors': '["Titilayo Omolara Johnson", "Titilayo Omolara", "Johnson", "Carlos Adam Conte-Junior", "Carlos Adam", "Conte-Junior"]'},
#  {'pmcid': 'A Cost Effective Scheme for the Highly Accurate Description of Intermolecular Binding in Large Complexes.',
#   'authors': '["Ji\\u0159\\u00ed Czernek", "Ji\\u0159\\u00ed", "Czernek", "Vladim\\u00edra Czernekov\\u00e1", "Vladim\\u00edra", "Czernekov\\u00e1"]'},
#  {'pmcid': 'A DNA Structural Alphabet Distinguishes Structural Features of DNA Bound to Regulatory Proteins and in the Nucleosome Core Particle.',
#   'authors': '["Bohdan Schneider", "Bohdan", "Schneider", "Ji\\u0159\\u00ed \\u010cern\\u00fd", "Ji\\u0159\\u00ed", "\\u010cern\\u00fd"]'},
#  {'pmcid': 'A DNA damage repair gene-associated signature predicts responses of patients with advanced soft-tissue sarcoma to treatment with trabectedin.',
#   'authors': '["David S Moura", "David S", "Moura", "Javier Mart\\u00edn-Broto", "Javier", "Mart\\u00edn-Broto"]'},
#  {'pmcid': 'A Fundamental Investigation of Gas/Solid Heat and Mass Transfer in Structured Catalysts Based on Periodic Open Cellular Structures (POCS).',
#   'authors': '["Claudio Ferroni", "Claudio", "Ferroni", "Enrico Tronconi", "Enrico", "Tronconi"]'},
#  {'pmcid': 'A Genome-Wide Association Study of a Biomarker of Nicotine Metabolism.',
#   'authors': '["Anu Loukola", "Anu", "Loukola", "Jaakko Kaprio", "Jaakko", "Kaprio"]'},
#  {'pmcid': 'A High-Quality Assembly of the Nine-Spined Stickleback (Pungitius pungitius) Genome.',
#   'authors': '["Srinidhi Varadharajan", "Srinidhi", "Varadharajan", "Juha Meril\\u00e4", "Juha", "Meril\\u00e4"]'},
#  {'pmcid': 'A Histone Deacetylase Inhibitor Induces Acetyl-CoA Depletion Leading to Lethal Metabolic Stress in RAS-Pathway Activated Cells.',
#   'authors': '["Agnes Basseville", "Agnes", "Basseville", "Susan E Bates", "Susan E", "Bates"]'},
#  {'pmcid': 'A Hybrid Hamiltonian for the Accelerated Sampling along Experimental Restraints.',
#   'authors': '["Emanuel K Peter", "Emanuel K", "Peter", "Ji\\u0159\\u00ed \\u010cern\\u00fd", "Ji\\u0159\\u00ed", "\\u010cern\\u00fd"]'},
#  {'pmcid': 'A Jupyter notebook to explore protein conformations: An output of PaNOSC SP8 case',
#   'authors': '["Irina Safiulina", "Irina", "Safiulina", "Enol Fern\\u00e1ndez", "Enol", "Fern\\u00e1ndez"]'},
#  {'pmcid': 'A Literature Review on Ethics for AI in Biomedical Research and Biobanking.',
#   'authors': '["Michaela Kargl", "Michaela", "Kargl", "Heimo M\\u00fcller", "Heimo", "M\\u00fcller"]'},
#  {'pmcid': 'A Low-Frequency Inactivating AKT2 Variant Enriched in the Finnish Population Is Associated With Fasting Insulin Levels and Type 2 Diabetes Risk.',
#   'authors': '["Alisa Manning", "Alisa", "Manning", "Cecilia M Lindgren", "Cecilia M", "Lindgren"]'},
#  {'pmcid': 'A Map of the Initiatives That Harmonize Patient Cohorts Across the World.',
#   'authors': '["\\u00c1ngel Rodr\\u00edguez-Laso", "\\u00c1ngel", "Rodr\\u00edguez-Laso", "Jos\\u00e9 Luis Ayuso", "Jos\\u00e9 Luis", "Ayuso"]'},
#  {'pmcid': 'A Methylotrophic Bacterium Growing with the Antidiabetic Drug Metformin as Its Sole Carbon, Nitrogen and Energy Source.',
#   'authors': '["Pauline Chaignaud", "Pauline", "Chaignaud", "St\\u00e9phane Vuilleumier", "St\\u00e9phane", "Vuilleumier"]'},
#  {'pmcid': 'A Mitochondrial Autonomously Replicating Sequence from Pichia pastoris for Uniform High Level Recombinant Protein Production.',
#   'authors': '["Jan-Philipp Schwarzhans", "Jan-Philipp", "Schwarzhans", "Karl Friehs", "Karl", "Friehs"]'},
#  {'pmcid': 'A Modular Metagenomics Pipeline Allowing for the Inclusion of Prior Knowledge Using the Example of Anaerobic Digestion.',
#   'authors': '["Daniela Becker", "Daniela", "Becker", "Florian Centler", "Florian", "Centler"]'},
#  {'pmcid': 'A Multisystem Mitochondrial Disease Caused by a Novel MT-TL1 mtDNA Variant: A Case Report.',
#   'authors': '["Domenico Giannese", "Domenico", "Giannese", "Michelangelo Mancuso", "Michelangelo", "Mancuso"]'},
#  {'pmcid': 'A New Technique for Determining Micronutrient Nutritional Quality in Fruits and Vegetables Based on the Entropy Weight Method and Fuzzy Recognition Method.',
#   'authors': '["Xuemei Zhao", "Xuemei", "Zhao", "Dazhou Zhu", "Dazhou", "Zhu"]'},
#  {'pmcid': 'A Puzzling Anomaly in the 4-Mer Composition of the Giant Pandoravirus Genomes Reveals a Stringent New Evolutionary Selection Process.',
#   'authors': '["Olivier Poirot", "Olivier", "Poirot", "Jean-Michel Claverie", "Jean-Michel", "Claverie"]'},
#  {'pmcid': 'A Querying Method over RDF-ized Health Level Seven v2.5 Messages Using Life Science Knowledge Resources.',
#   'authors': '["Yoshimasa Kawazoe", "Yoshimasa", "Kawazoe", "Kazuhiko Ohe", "Kazuhiko", "Ohe"]'},
#  {'pmcid': 'A Rat Model of Clinically Relevant Extracorporeal Circulation Develops Early Organ Dysfunctions.',
#   'authors': '["Antoine Persello", "Antoine", "Persello", "Benjamin Lauzier", "Benjamin", "Lauzier"]'},
#  {'pmcid': 'A Recurrent VPS16 p.Arg187* Nonsense Variant in Early-Onset Generalized Dystonia.',
#   'authors': '["Miriama Ostrozovicova", "Miriama", "Ostrozovicova", "Matej Skorvanek", "Matej", "Skorvanek"]'},
#  {'pmcid': 'A Reference Genome Sequence for the European Silver Fir (Abies alba Mill.): A Community-Generated Genomic Resource.',
#   'authors': '["Elena Mosca", "Elena", "Mosca", "David B Neale", "David B", "Neale"]'},
#  {'pmcid': 'A Review on Viral Data Sources and Integration Methods for COVID-19 Mitigation',
#   'authors': '["Anna Bernasconi", "Anna", "Bernasconi", "Stefano Ceri", "Stefano", "Ceri"]'},
#  {'pmcid': 'A Robust and Universal Metaproteomics Workflow for Research Studies and Routine Diagnostics Within 24 h Using Phenol Extraction, FASP Digest, and the MetaProteomeAnalyzer.',
#   'authors': '["Robert Heyer", "Robert", "Heyer", "Dirk Benndorf", "Dirk", "Benndorf"]'},
#  {'pmcid': 'A Role for Human DNA Polymerase λ in Alternative Lengthening of Telomeres.',
#   'authors': '["Elisa Mentegari", "Elisa", "Mentegari", "Giovanni Maga", "Giovanni", "Maga"]'},
#  {'pmcid': 'A SARS-CoV-2 cytopathicity dataset generated by high-content screening of a large drug repurposing collection.',
#   'authors': '["Bernhard Ellinger", "Bernhard", "Ellinger", "Sandra Ciesek", "Sandra", "Ciesek"]'},
#  {'pmcid': 'A SARS-CoV-2 sequence submission tool for the European Nucleotide Archive.',
#   'authors': '["Miguel Roncoroni", "Miguel", "Roncoroni", "Frederik Coppens", "Frederik", "Coppens"]'},
#  {'pmcid': 'A Sample Preparation Method for the Simultaneous Profiling of Signaling Lipids and Polar Metabolites in Small Quantities of Muscle Tissues from a Mouse Model for Sarcopenia.',
#   'authors': '["Yupeng He", "Yupeng", "He", "Thomas Hankemeier", "Thomas", "Hankemeier"]'},
#  {'pmcid': 'A Semi-automated Organoid Screening Method Demonstrates Epigenetic Control of Intestinal Epithelial Differentiation.',
#   'authors': '["Jenny Ostrop", "Jenny", "Ostrop", "Menno J Oudhoff", "Menno J", "Oudhoff"]'},
#  {'pmcid': 'A Simple Standard for Sharing Ontological Mappings (SSSOM).',
#   'authors': '["Nicolas Matentzoglu", "Nicolas", "Matentzoglu", "Christopher J Mungall", "Christopher J", "Mungall"]'},
#  {'pmcid': 'A Simple and Fast Assay Based on Carboxyfluorescein-Loaded Liposome for Quantitative DNA Detection.',
#   'authors': '["Jacopo Sforzi", "Jacopo", "Sforzi", "Simonetta Geninatti Crich", "Simonetta", "Geninatti Crich"]'},
#  {'pmcid': 'A Simple, Test-Based Method to Control the Overestimation Bias in the Analysis of Potential Prognostic Tumour Markers.',
#   'authors': '["Marzia Ognibene", "Marzia", "Ognibene", "Stefano Parodi", "Stefano", "Parodi"]'},
#  {'pmcid': 'A Strong Seasonality Pattern for Covid-19 Incidence Rates Modulated by UV Radiation Levels.',
#   'authors': '["Christos Karapiperis", "Christos", "Karapiperis", "Christos A Ouzounis", "Christos A", "Ouzounis"]'},
#  {'pmcid': 'A Tetragenococcus halophilus human gut isolate.',
#   'authors': '["Cheick Oumar Guindo", "Cheick Oumar", "Guindo", "Ghiles Grine", "Ghiles", "Grine"]'},
#  {'pmcid': 'A Volumetric Analysis of the 1H NMR Chemical Shielding in Supramolecular Systems.',
#   'authors': '["Ji\\u0159\\u00ed Czernek", "Ji\\u0159\\u00ed", "Czernek", "Ji\\u0159\\u00ed Brus", "Ji\\u0159\\u00ed", "Brus"]'},
#  {'pmcid': 'A YAP/TAZ-ARHGAP29-RhoA Signaling Axis Regulates Podocyte Protrusions and Integrin Adhesions.',
#   'authors': '["Manuel Rogg", "Manuel", "Rogg", "Christoph Schell", "Christoph", "Schell"]'},
#  {'pmcid': 'A benchmark of hemoglobin blocking during library preparation for mRNA-Sequencing of human blood samples.',
#   'authors': '["Florian Uellendahl-Werth", "Florian", "Uellendahl-Werth", "David Ellinghaus", "David", "Ellinghaus"]'},
#  {'pmcid': 'A benchmark study of ab initio gene prediction methods in diverse eukaryotic organisms.',
#   'authors': '["Nicolas Scalzitti", "Nicolas", "Scalzitti", "Julie D Thompson", "Julie D", "Thompson"]'},
#  {'pmcid': 'A case of novel DYT6 dystonia variant with serious complications after deep brain stimulation therapy: a case report.',
#   'authors': '["M Grofik", "M", "Grofik", "R Jech", "R", "Jech"]'},
#  {'pmcid': 'A case study of salivary microbiome in smokers and non-smokers in Hungary: analysis by shotgun metagenome sequencing.',
#   'authors': '["Roland Wirth", "Roland", "Wirth", "Korn\\u00e9l L Kov\\u00e1cs", "Korn\\u00e9l L", "Kov\\u00e1cs"]'},
#  {'pmcid': 'A catalogue of 863 Rett-syndrome-causing MECP2 mutations and lessons learned from data integration.',
#   'authors': '["Friederike Ehrhart", "Friederike", "Ehrhart", "Chris T Evelo", "Chris T", "Evelo"]'},
#  {'pmcid': 'A chromosome-length genome assembly and annotation of blackberry (Rubus argutus, cv. "Hillquist").',
#   'authors': '["Tom\\u00e1\\u0161 Br\\u016fna", "Tom\\u00e1\\u0161", "Br\\u016fna", "Margaret Worthington", "Margaret", "Worthington"]'},
#  {'pmcid': 'A citizen-science-enabled catalogue of the vaginal microbiome and associated factors.',
#   'authors': '["Sarah Lebeer", "Sarah", "Lebeer", "Veronique Verhoeven", "Veronique", "Verhoeven"]'},
#  {'pmcid': 'A cluster of broadly neutralizing IgG against BK polyomavirus in a repertoire dominated by IgM.',
#   'authors': '["Ngoc-Khanh Nguyen", "Ngoc-Khanh", "Nguyen", "Dorian McIlroy", "Dorian", "McIlroy"]'},
#  {'pmcid': 'A community challenge for a pancancer drug mechanism of action inference from perturbational profile data.',
#   'authors': '["Eugene F Douglass", "Eugene F", "Douglass", "Andrea Califano", "Andrea", "Califano"]'},
#  {'pmcid': 'A community proposal to integrate proteomics activities in ELIXIR',
#   'authors': '["Juan Antonio Vizca\\u00edno", "Juan Antonio", "Vizca\\u00edno", "Oliver Kohlbacher", "Oliver", "Kohlbacher"]'},
#  {'pmcid': 'A community proposal to integrate proteomics activities in ELIXIR.',
#   'authors': '["Juan Antonio Vizca\\u00edno", "Juan Antonio", "Vizca\\u00edno", "Oliver Kohlbacher", "Oliver", "Kohlbacher"]'},
#  {'pmcid': 'A community proposal to integrate structural bioinformatics activities in ELIXIR (3D-Bioinfo Community)',
#   'authors': '["Christine Orengo", "Christine", "Orengo", "Bohdan Schneider", "Bohdan", "Schneider"]'},
#  {'pmcid': 'A community proposal to integrate structural bioinformatics activities in ELIXIR (3D-Bioinfo Community).',
#   'authors': '["Christine Orengo", "Christine", "Orengo", "Bohdan Schneider", "Bohdan", "Schneider"]'},
#  {'pmcid': 'A comparison of approaches to accessing existing biological and chemical relational databases via SPARQL.',
#   'authors': '["Jakub Galgonek", "Jakub", "Galgonek", "Ji\\u0159\\u00ed Vondr\\u00e1\\u0161ek", "Ji\\u0159\\u00ed", "Vondr\\u00e1\\u0161ek"]'},
#  {'pmcid': 'A comparison of mechanistic signaling pathway activity analysis methods.',
#   'authors': '["Alicia Amadoz", "Alicia", "Amadoz", "Joaqu\\u00edn Dopazo", "Joaqu\\u00edn", "Dopazo"]'},
#  {'pmcid': 'A comprehensive analysis of the Lactuca sativa, L. transcriptome during different stages of the compatible interaction with Rhizoctonia solani.',
#   'authors': '["Bart Verwaaijen", "Bart", "Verwaaijen", "Andreas Schl\\u00fcter", "Andreas", "Schl\\u00fcter"]'},
#  {'pmcid': 'A comprehensive assessment of somatic mutation detection in cancer using whole-genome sequencing.',
#   'authors': '["Tyler S Alioto", "Tyler S", "Alioto", "Ivo G Gut", "Ivo G", "Gut"]'},
#  {'pmcid': 'A comprehensive database for integrated analysis of omics data in autoimmune diseases.',
#   'authors': '["Jordi Martorell-Marug\\u00e1n", "Jordi", "Martorell-Marug\\u00e1n", "Pedro Carmona-S\\u00e1ez", "Pedro", "Carmona-S\\u00e1ez"]'},
#  {'pmcid': 'A comprehensive database of squirrel distribution and occurrence in South Asia.',
#   'authors': '["Udayraj Swati", "Udayraj", "Swati", "Nandini Rajamani", "Nandini", "Rajamani"]'},
#  {'pmcid': 'A comprehensive overview of microbiome data in the light of machine learning applications: categorization, accessibility, and future directions.',
#   'authors': '["Bablu Kumar", "Bablu", "Kumar", "Graziano Pesole", "Graziano", "Pesole"]'},
#  {'pmcid': 'A concentric circles view of health data relations facilitates understanding of sociotechnical challenges for learning health systems and the role of federated data networks.',
#   'authors': '["Richard Milne", "Richard", "Milne", "Nigel Hughes", "Nigel", "Hughes"]'},
#  {'pmcid': 'A crowdsourcing database for the copy-number variation of the Spanish population.',
#   'authors': '["Daniel L\\u00f3pez-L\\u00f3pez", "Daniel", "L\\u00f3pez-L\\u00f3pez", "Joaquin Dopazo", "Joaquin", "Dopazo"]'},
#  {'pmcid': 'A crowdsourcing workflow for extracting chemical-induced disease relations from free text.',
#   'authors': '["Tong Shu Li", "Tong Shu", "Li", "Andrew I Su", "Andrew I", "Su"]'},
#  {'pmcid': 'A dataset for assessing phytolith data for implementation of the FAIR data principles.',
#   'authors': '["C\\u00e9line Kerfant", "C\\u00e9line", "Kerfant", "Emma Karoune", "Emma", "Karoune"]'},
#  {'pmcid': 'A de novo STUB1 variant associated with an early adult-onset multisystemic ataxia phenotype.',
#   'authors': '["David Mengel", "David", "Mengel", "Matthis Synofzik", "Matthis", "Synofzik"]'},
#  {'pmcid': 'A design framework and exemplar metrics for FAIRness.',
#   'authors': '["Mark D Wilkinson", "Mark D", "Wilkinson", "Michel Dumontier", "Michel", "Dumontier"]'},
#  {'pmcid': 'A digital repository with an extensible data model for biobanking and genomic analysis management.',
#   'authors': '["Massimiliano Izzo", "Massimiliano", "Izzo", "Luigi Varesio", "Luigi", "Varesio"]'},
#  {'pmcid': 'A federated authentication schema among multiple identity providers.',
#   'authors': '["Jo\\u00e3o Rafael Almeida", "Jo\\u00e3o Rafael", "Almeida", "Jos\\u00e9 Lu\\u00eds Oliveira", "Jos\\u00e9 Lu\\u00eds", "Oliveira"]'},
#  {'pmcid': 'A framework to assess the quality and impact of bioinformatics training across ELIXIR.',
#   'authors': '["Kim T Gurwitz", "Kim T", "Gurwitz", "Gabriella Rustici", "Gabriella", "Rustici"]'},
#  {'pmcid': 'A gaps-and-needs analysis of vaccine R&D in Europe: Recommendations to improve the research infrastructure.',
#   'authors': '["Stefan Jungbluth", "Stefan", "Jungbluth", "Laurent Beloeil", "Laurent", "Beloeil"]'},
#  {'pmcid': 'A gene expression atlas for different kinds of stress in the mouse brain.',
#   'authors': '["Tiziano Flati", "Tiziano", "Flati", "Tiziana Castrignan\\u00f2", "Tiziana", "Castrignan\\u00f2"]'},
#  {'pmcid': 'A gene-expression module in circulating immune cells is associated with cell migration during immune diseases',
#   'authors': '["Thomas Laurent", "Thomas", "Laurent", "Jeremie Poschmann", "Jeremie", "Poschmann"]'},
#  {'pmcid': 'A generally applicable lightweight method for calculating a value structure for tools and services in bioinformatics infrastructure projects.',
#   'authors': '["Gerhard Mayer", "Gerhard", "Mayer", "Martin Eisenacher", "Martin", "Eisenacher"]'},
#  {'pmcid': 'A genomic platform for surveillance and antigen discovery in Plasmodium spp. using long-read amplicon sequencing.',
#   'authors': '["David Fernando Plaza", "David Fernando", "Plaza", "Anna F\\u00e4rnert", "Anna", "F\\u00e4rnert"]'},
#  {'pmcid': 'A genotype-first approach to exploring Mendelian cardiovascular traits with clear external manifestations.',
#   'authors': '["Brittany M Wenger", "Brittany M", "Wenger", "Bruce D Gelb", "Bruce D", "Gelb"]'},
#  {'pmcid': 'A glial signal consisting of gliomedin and NrCAM clusters axonal Na+ channels during the formation of nodes of Ranvier.',
#   'authors': '["Konstantin Feinberg", "Konstantin", "Feinberg", "Elior Peles", "Elior", "Peles"]'},
#  {'pmcid': 'A global perspective on evolving bioinformatics and data science training needs.',
#   'authors': '["Teresa K Attwood", "Teresa K", "Attwood", "Maria Victoria Schneider", "Maria Victoria", "Schneider"]'},
#  {'pmcid': 'A goal-oriented method for FAIRification planning',
#   'authors': '["C\\u00e9sar Bernab\\u00e9", "C\\u00e9sar", "Bernab\\u00e9", "Marco Roos", "Marco", "Roos"]'},
#  {'pmcid': 'A guide for developing comprehensive systems biology maps of disease mechanisms: planning, construction and maintenance.',
#   'authors': '["Alexander Mazein", "Alexander", "Mazein", "Marek Ostaszewski", "Marek", "Ostaszewski"]'},
#  {'pmcid': 'A guide to naming human non-coding RNA genes.',
#   'authors': '["Ruth L Seal", "Ruth L", "Seal", "Elspeth A Bruford", "Elspeth A", "Bruford"]'},
#  {'pmcid': 'A heterozygous germline CD100 mutation in a family with primary sclerosing cholangitis.',
#   'authors': '["Xiaojun Jiang", "Xiaojun", "Jiang", "Espen Melum", "Espen", "Melum"]'},
#  {'pmcid': 'A high resolution A-to-I editing map in the mouse identifies editing events controlled by pre-mRNA splicing.',
#   'authors': '["Konstantin Licht", "Konstantin", "Licht", "Michael F Jantsch", "Michael F", "Jantsch"]'},
#  {'pmcid': 'A knowledge graph approach to predict and interpret disease-causing gene interactions.',
#   'authors': '["Alexandre Renaux", "Alexandre", "Renaux", "Tom Lenaerts", "Tom", "Lenaerts"]'},
#  {'pmcid': 'A library of sensitive position-specific scoring matrices for high-throughput identification of nuclear pore complex subunits.',
#   'authors': '["Andreas N Ioannides", "Andreas N", "Ioannides", "Vasilis J Promponas", "Vasilis J", "Promponas"]'},
#  {'pmcid': 'A meta-analysis of Italian and Estonian individuals shows an effect of common variants in HMGCR on blood apoB levels.',
#   'authors': '["Martina Rosticci", "Martina", "Rosticci", "Inga Prokopenko", "Inga", "Prokopenko"]'},
#  {'pmcid': 'A metabolic core model elucidates how enhanced utilization of glucose and glutamine, with enhanced glutamine-dependent lactate production, promotes cancer cell growth: The WarburQ effect.',
#   'authors': '["Chiara Damiani", "Chiara", "Damiani", "Lilia Alberghina", "Lilia", "Alberghina"]'},
#  {'pmcid': 'A metadata schema for data objects in clinical research.',
#   'authors': '["Steve Canham", "Steve", "Canham", "Christian Ohmann", "Christian", "Ohmann"]'},
#  {'pmcid': 'A metagenomic insight into the microbiomes of geothermal springs in the Subantarctic Kerguelen Islands.',
#   'authors': '["Maxime Allioux", "Maxime", "Allioux", "Karine Alain", "Karine", "Alain"]'},
#  {'pmcid': 'A mini-review on perturbation modelling across single-cell omic modalities.',
#   'authors': '["George I Gavriilidis", "George I", "Gavriilidis", "Fotis Psomopoulos", "Fotis", "Psomopoulos"]'},
#  {'pmcid': 'A minimal metadata set (MNMS) to repurpose nonclinical in vivo data for biomedical research.',
#   'authors': '["Anastasios Moresis", "Anastasios", "Moresis", "Alexandra Bannach-Brown", "Alexandra", "Bannach-Brown"]'},
#  {'pmcid': 'A model industrial workhorse: Bacillus subtilis strain 168 and its genome after a quarter of a century.',
#   'authors': '["Erhard Bremer", "Erhard", "Bremer", "Cristal Zuniga", "Cristal", "Zuniga"]'},
#  {'pmcid': 'A mosaic PIK3CA variant in a young adult with diffuse gastric cancer: case report.',
#   'authors': '["Iris B A W Te Paske", "Iris B A W", "Te Paske", "Richarda M de Voer", "Richarda M", "de Voer"]'},
#  {'pmcid': 'A mouse model of Schwartz-Jampel syndrome reveals myelinating Schwann cell dysfunction with persistent axonal depolarization in vitro and distal peripheral nerve hyperexcitability when perlecan is lacking.',
#   'authors': '["Marie Bangratz", "Marie", "Bangratz", "Sophie Nicole", "Sophie", "Nicole"]'},
#  {'pmcid': 'A multi-objective genetic algorithm to find active modules in multiplex biological networks.',
#   'authors': '["Elva Mar\\u00eda Novoa-Del-Toro", "Elva Mar\\u00eda", "Novoa-Del-Toro", "Ana\\u00efs Baudot", "Ana\\u00efs", "Baudot"]'},
#  {'pmcid': 'A multi-omics analysis reveals the unfolded protein response regulon and stress-induced resistance to folate-based antimetabolites.',
#   'authors': '["Stefan Reich", "Stefan", "Reich", "Jan Medenbach", "Jan", "Medenbach"]'},
#  {'pmcid': 'A multiple network-based bioinformatics pipeline for the study of molecular mechanisms in oncological diseases for personalized medicine.',
#   'authors': '["Serena Dotolo", "Serena", "Dotolo", "Roberto Tagliaferri", "Roberto", "Tagliaferri"]'},
#  {'pmcid': 'A neutral comparison of statistical methods for analyzing longitudinally measured ordinal outcomes in rare diseases.',
#   'authors': '["Martin Geroldinger", "Martin", "Geroldinger", "Georg Zimmermann", "Georg", "Zimmermann"]'},
#  {'pmcid': 'A new genetic cause of spastic ataxia: the p.Glu415Lys variant in TUBA4A.',
#   'authors': '["Annalaura Torella", "Annalaura", "Torella", "Alessandro Filla", "Alessandro", "Filla"]'},
#  {'pmcid': 'A new genomic blueprint of the human gut microbiota.',
#   'authors': '["Alexandre Almeida", "Alexandre", "Almeida", "Robert D Finn", "Robert D", "Finn"]'},
#  {'pmcid': "A new molecular classification to drive precision treatment strategies in primary Sjögren's syndrome.",
#   'authors': '["Perrine Soret", "Perrine", "Soret", "Jacques-Olivier Pers", "Jacques-Olivier", "Pers"]'},
#  {'pmcid': 'A new pan-European Train-the-Trainer programme for bioinformatics: pilot results on feasibility, utility and sustainability of learning.',
#   'authors': '["Allegra Via", "Allegra", "Via", "Rochelle E Tractenberg", "Rochelle E", "Tractenberg"]'},
#  {'pmcid': 'A novel biomarker for Ataxia-Telangiectasia: Evaluating the lack of hypointensity of the dentate nuclei',
#   'authors': '["May Yung Tiet", "May Yung", "Tiet", "Anke Hensiek", "Anke", "Hensiek"]'},
#  {'pmcid': 'A novel insight into neurological disorders through HDAC6 protein-protein interactions.',
#   'authors': '["Nasim Bahram Sangani", "Nasim", "Bahram Sangani", "Lars M T Eijssen", "Lars M T", "Eijssen"]'},
#  {'pmcid': 'A nox2/cybb zebrafish mutant with defective myeloid cell reactive oxygen species production displays normal initial neutrophil recruitment to sterile tail injuries.',
#   'authors': '["Abdulsalam I Isiaku", "Abdulsalam I", "Isiaku", "Graham J Lieschke", "Graham J", "Lieschke"]'},
#  {'pmcid': 'A pipeline-friendly software tool for genome diagnostics to prioritize genes by matching patient symptoms to literature.',
#   'authors': '["K Joeri van der Velde", "K Joeri", "van der Velde", "Morris A Swertz", "Morris A", "Swertz"]'},
#  {'pmcid': 'A plugin for the Ensembl Variant Effect Predictor that uses MaxEntScan to predict variant spliceogenicity.',
#   'authors': '["Jannah Shamsani", "Jannah", "Shamsani", "Amanda B Spurdle", "Amanda B", "Spurdle"]'},
#  {'pmcid': 'A polymorphic AT-repeat causes frequent allele dropout for an MME mutational hotspot exon.',
#   'authors': '["Helle H\\u00f8yer", "Helle", "H\\u00f8yer", "Michaela Auer-Grumbach", "Michaela", "Auer-Grumbach"]'},
#  {'pmcid': 'A possible S-glutathionylation of specific proteins by glyoxalase II: An in vitro and in silico study.',
#   'authors': '["Luisa Ercolani", "Luisa", "Ercolani", "Tatiana Armeni", "Tatiana", "Armeni"]'},
#  {'pmcid': 'A primer on machine learning techniques for genomic applications.',
#   'authors': '["Alfonso Monaco", "Alfonso", "Monaco", "Roberto Bellotti", "Roberto", "Bellotti"]'},
#  {'pmcid': 'A property-response perspective on modern toxicity assessment and drug toxicity index (DTI).',
#   'authors': '["Vaibhav A Dixit", "Vaibhav A", "Dixit", "Pragati Singh", "Pragati", "Singh"]'},
#  {'pmcid': 'A proteomics sample metadata representation for multiomics integration and big data analysis.',
#   'authors': '["Chengxin Dai", "Chengxin", "Dai", "Yasset Perez-Riverol", "Yasset", "Perez-Riverol"]'},
#  {'pmcid': 'A protocol for adding knowledge to Wikidata, a case report',
#   'authors': '["Andra Waagmeester", "Andra", "Waagmeester", "Jasper Koehorst", "Jasper", "Koehorst"]'},
#  {'pmcid': 'A quality control portal for sequencing data deposited at the European genome-phenome archive.',
#   'authors': '["Dietmar Fern\\u00e1ndez-Orth", "Dietmar", "Fern\\u00e1ndez-Orth", "Jordi Rambla", "Jordi", "Rambla"]'},
#  {'pmcid': 'A quick guide for building a successful bioinformatics community.',
#   'authors': '["Aidan Budd", "Aidan", "Budd", "Niklas Blomberg", "Niklas", "Blomberg"]'},
#  {'pmcid': 'A reference genome of the Chinese hamster based on a hybrid assembly strategy.',
#   'authors': '["Oliver Rupp", "Oliver", "Rupp", "Kelvin H Lee", "Kelvin H", "Lee"]'},
#  {'pmcid': 'A reproducible workflow for assembling the mitochondrial genome of Acheta domesticus (Orthoptera: Gryllidae).',
#   'authors': '["Somjit Homchan", "Somjit", "Homchan", "Yash Munnalal Gupta", "Yash Munnalal", "Gupta"]'},
#  {'pmcid': 'A research data management (RDM) community for ELIXIR',
#   'authors': '["Flora D\'Anna", "Flora", "D\'Anna", "Munazah Andrabi", "Munazah", "Andrabi"]'},
#  {'pmcid': 'A resource to explore the discovery of rare diseases and their causative genes.',
#   'authors': '["Friederike Ehrhart", "Friederike", "Ehrhart", "Chris T Evelo", "Chris T", "Evelo"]'},
#  {'pmcid': 'A review of bioinformatics platforms for comparative genomics. Recent developments of the EDGAR 2.0 platform and its utility for taxonomic and phylogenetic studies.',
#   'authors': '["J Yu", "J", "Yu", "A Goesmann", "A", "Goesmann"]'},
#  {'pmcid': 'A review on drug repurposing applicable to COVID-19.',
#   'authors': '["Serena Dotolo", "Serena", "Dotolo", "Roberto Tagliaferri", "Roberto", "Tagliaferri"]'},
#  {'pmcid': 'A review on viral data sources and search systems for perspective mitigation of COVID-19.',
#   'authors': '["Anna Bernasconi", "Anna", "Bernasconi", "Stefano Ceri", "Stefano", "Ceri"]'},
#  {'pmcid': 'A rigorous evaluation of optimal peptide targets for MS-based clinical diagnostics of Coronavirus Disease 2019 (COVID-19)',
#   'authors': '["Andrew Rajczewski", "Andrew", "Rajczewski", "Pratik Jagtap", "Pratik", "Jagtap"]'},
#  {'pmcid': 'A rigorous evaluation of optimal peptide targets for MS-based clinical diagnostics of Coronavirus Disease 2019 (COVID-19).',
#   'authors': '["Andrew T Rajczewski", "Andrew T", "Rajczewski", "Pratik D Jagtap", "Pratik D", "Jagtap"]'},
#  {'pmcid': 'A roadmap for the generation of benchmarking resources for antimicrobial resistance detection using next generation sequencing.',
#   'authors': '["Mauro Petrillo", "Mauro", "Petrillo", "Alexandre Angers-Loustau", "Alexandre", "Angers-Loustau"]'},
#  {'pmcid': 'A roadmap towards personalized immunology.',
#   'authors': '["Sylvie Delhalle", "Sylvie", "Delhalle", "Feng Q He", "Feng Q", "He"]'},
#  {'pmcid': 'A single alcohol binge impacts on neutrophil function without changes in gut barrier function and gut microbiome composition in healthy volunteers.',
#   'authors': '["Vanessa Stadlbauer", "Vanessa", "Stadlbauer", "Bettina Leber", "Bettina", "Leber"]'},
#  {'pmcid': 'A single cell RNAseq benchmark experiment embedding "controlled" cancer heterogeneity.',
#   'authors': '["Maddalena Arigoni", "Maddalena", "Arigoni", "Luca Alessandri", "Luca", "Alessandri"]'},
#  {'pmcid': 'A single-cell RNA-sequencing training and analysis suite using the Galaxy framework.',
#   'authors': '["Mehmet Tekman", "Mehmet", "Tekman", "Bj\\u00f6rn Gr\\u00fcning", "Bj\\u00f6rn", "Gr\\u00fcning"]'},
#  {'pmcid': 'A snapshot of 3649 Web-based services published between 1994 and 2017 shows a decrease in availability after 2 years.',
#   'authors': '["\\u00c1gnes \\u0150sz", "\\u00c1gnes", "\\u0150sz", "Bal\\u00e1zs Gy\\u0151rffy", "Bal\\u00e1zs", "Gy\\u0151rffy"]'},
#  {'pmcid': 'A streamlined workflow for conversion, peer review, and publication of genomics metadata as omics data papers.',
#   'authors': '["Mariya Dimitrova", "Mariya", "Dimitrova", "Lyubomir Penev", "Lyubomir", "Penev"]'},
#  {'pmcid': 'A study of deep active learning methods to reduce labelling efforts in biomedical relation extraction.',
#   'authors': '["Charlotte Nachtegael", "Charlotte", "Nachtegael", "Tom Lenaerts", "Tom", "Lenaerts"]'},
#  {'pmcid': 'A systematic comparison of FOSL1, FOSL2 and BATF-mediated transcriptional regulation during early human Th17 differentiation.',
#   'authors': '["Ankitha Shetty", "Ankitha", "Shetty", "Riitta Lahesmaa", "Riitta", "Lahesmaa"]'},
#  {'pmcid': 'A three-feature prediction model for metastasis-free survival after surgery of localized clear cell renal cell carcinoma.',
#   'authors': '["Kalle E Mattila", "Kalle E", "Mattila", "Panu M Jaakkola", "Panu M", "Jaakkola"]'},
#  {'pmcid': 'A tool for assessing alignment of biomedical data repositories with open, FAIR, citation and trustworthy principles.',
#   'authors': '["Fiona Murphy", "Fiona", "Murphy", "Maryann E Martone", "Maryann E", "Martone"]'},
#  {'pmcid': 'A unidirectional mapping of ICD-8 to ICD-10 codes, for harmonized longitudinal analysis of diseases.',
#   'authors': '["Mette Krogh Pedersen", "Mette Krogh", "Pedersen", "S\\u00f8ren Brunak", "S\\u00f8ren", "Brunak"]'},
#  {'pmcid': 'A unified dinucleotide alphabet describing both RNA and DNA structures.',
#   'authors': '["Ji\\u0159\\u00ed \\u010cern\\u00fd", "Ji\\u0159\\u00ed", "\\u010cern\\u00fd", "Bohdan Schneider", "Bohdan", "Schneider"]'},
#  {'pmcid': 'A unified platform enabling biomarker ranking and validation for 1562 drugs using transcriptomic data of 1250 cancer cell lines.',
#   'authors': '["J\\u00e1nos Tibor Fekete", "J\\u00e1nos", "Tibor Fekete", "Bal\\u00e1zs Gy\\u0151rffy", "Bal\\u00e1zs", "Gy\\u0151rffy"]'},
#  {'pmcid': 'A vaccine targeting antigen-presenting cells through CD40 induces protective immunity against Nipah disease.',
#   'authors': '["Yadira Pastor", "Yadira", "Pastor", "Sylvain Cardinaud", "Sylvain", "Cardinaud"]'},
#  {'pmcid': 'A versatile workflow to integrate RNA-seq genomic and transcriptomic data into mechanistic models of signaling pathways.',
#   'authors': '["Mart\\u00edn Garrido-Rodriguez", "Mart\\u00edn", "Garrido-Rodriguez", "Joaquin Dopazo", "Joaquin", "Dopazo"]'},
#  {'pmcid': 'A vision and strategy for the virtual physiological human: 2012 update.',
#   'authors': '["Peter Hunter", "Peter", "Hunter", "Marco Viceconti", "Marco", "Viceconti"]'},
#  {'pmcid': 'A walk in the PARC: developing and implementing 21st century chemical risk assessment in Europe.',
#   'authors': '["P Marx-Stoelting", "P", "Marx-Stoelting", "P Sanders", "P", "Sanders"]'},
#  {'pmcid': 'A whirl of radiomics-based biomarkers in cancer immunotherapy, why is large scale validation still lacking?',
#   'authors': '["Marta Ligero", "Marta", "Ligero", "Raquel Perez-Lopez", "Raquel", "Perez-Lopez"]'},
#  {'pmcid': 'A widespread inversion polymorphism conserved among Saccharomyces species is caused by recurrent homogenization of a sporulation gene family.',
#   'authors': '["Letal I Salzberg", "Letal I", "Salzberg", "Kenneth H Wolfe", "Kenneth H", "Wolfe"]'},
#  {'pmcid': 'A workflow reproducibility scale for automatic validation of biological interpretation results.',
#   'authors': '["Hirotaka Suetake", "Hirotaka", "Suetake", "Tazro Ohta", "Tazro", "Ohta"]'},
#  {'pmcid': 'A-GAME: improving the assembly of pooled functional metagenomics sequence data.',
#   'authors': '["Matteo Chiara", "Matteo", "Chiara", "Graziano Pesole", "Graziano", "Pesole"]'},
#  {'pmcid': 'A-to-I RNA editing in SARS-COV-2: real or artifact?',
#   'authors': '["Ernesto Picardi", "Ernesto", "Picardi", "Graziano Pesole", "Graziano", "Pesole"]'},
#  {'pmcid': 'ABCA4 Variant c.5714+5G>A in Trans With Null Alleles Results in Primary RPE Damage.',
#   'authors': '["Jana Sajovic", "Jana", "Sajovic", "Ana Fakin", "Ana", "Fakin"]'},
#  {'pmcid': 'ABCA4 c.6480-35A>G, a novel branchpoint variant associated with Stargardt disease.',
#   'authors': '["Mar\\u00eda Rodr\\u00edguez-Hidalgo", "Mar\\u00eda", "Rodr\\u00edguez-Hidalgo", "Susanne Roosing", "Susanne", "Roosing"]'},
#  {'pmcid': 'ABRF Proteome Informatics Research Group (iPRG) 2016 Study: Inferring Proteoforms from Bottom-up Proteomics Data.',
#   'authors': '["Joon-Yong Lee", "Joon-Yong", "Lee", "Magnus Palmblad", "Magnus", "Palmblad"]'},
#  {'pmcid': 'AGAMEMNON: an Accurate metaGenomics And MEtatranscriptoMics quaNtificatiON analysis suite.',
#   'authors': '["Giorgos Skoufos", "Giorgos", "Skoufos", "Ioannis S Vlachos", "Ioannis S", "Vlachos"]'},
#  {'pmcid': 'AHoJ: rapid, tailored search and retrieval of apo and holo protein structures for user-defined ligands.',
#   'authors': '["Christos P Feidakis", "Christos P", "Feidakis", "Marian Novotny", "Marian", "Novotny"]'},
#  {'pmcid': 'AIUPred: combining energy estimation with deep learning for the enhanced prediction of protein disorder.',
#   'authors': '["G\\u00e1bor Erd\\u0151s", "G\\u00e1bor", "Erd\\u0151s", "Zsuzsanna Doszt\\u00e1nyi", "Zsuzsanna", "Doszt\\u00e1nyi"]'},
#  {'pmcid': 'ALK5 kinase inhibitory activity and synthesis of 2,3,4-substituted 5,5-dimethyl-5,6-dihydro-4H-pyrrolo[1,2-b]pyrazoles.',
#   'authors': '["Eva \\u0158ezn\\u00ed\\u010dkov\\u00e1", "Eva", "\\u0158ezn\\u00ed\\u010dkov\\u00e1", "Vladim\\u00edr Kry\\u0161tof", "Vladim\\u00edr", "Kry\\u0161tof"]'},
#  {'pmcid': 'ANASTASIA: An Automated Metagenomic Analysis Pipeline for Novel Enzyme Discovery Exploiting Next Generation Sequencing Data.',
#   'authors': '["Theodoros Koutsandreas", "Theodoros", "Koutsandreas", "Aristotelis A Chatziioannou", "Aristotelis A", "Chatziioannou"]'},
#  {'pmcid': 'ANISEED 2017: extending the integrated ascidian database to the exploration and evolutionary comparison of genome-scale datasets.',
#   'authors': '["Matija Brozovic", "Matija", "Brozovic", "Patrick Lemaire", "Patrick", "Lemaire"]'},
#  {'pmcid': 'ANISEED 2019: 4D exploration of genetic data for an extended range of tunicates.',
#   'authors': '["Justine Dardaillon", "Justine", "Dardaillon", "Patrick Lemaire", "Patrick", "Lemaire"]'},
#  {'pmcid': 'APE in the Wild: Automated Exploration of Proteomics Workflows in the bio.tools Registry.',
#   'authors': '["Vedran Kasalica", "Vedran", "Kasalica", "Anna-Lena Lamprecht", "Anna-Lena", "Lamprecht"]'},
#  {'pmcid': 'APICURON: a database to credit and acknowledge the work of biocurators.',
#   'authors': '["Andr\\u00e1s Hatos", "Andr\\u00e1s", "Hatos", "Silvio C E Tosatto", "Silvio C E", "Tosatto"]'},
#  {'pmcid': 'ARGprofiler-a pipeline for large-scale analysis of antimicrobial resistance genes and their flanking regions in metagenomic datasets.',
#   'authors': '["Hannah-Marie Martiny", "Hannah-Marie", "Martiny", "Patrick Munk", "Patrick", "Munk"]'},
#  {'pmcid': 'ARIAweb: a server for automated NMR structure calculation.',
#   'authors': '["Fabrice Allain", "Fabrice", "Allain", "Benjamin Bardiaux", "Benjamin", "Bardiaux"]'},
#  {'pmcid': 'ARL15 modulates magnesium homeostasis through N-glycosylation of CNNMs.',
#   'authors': '["Yevgen Zolotarov", "Yevgen", "Zolotarov", "Jeroen H F de Baaij", "Jeroen H F", "de Baaij"]'},
#  {'pmcid': 'ARPIR: automatic RNA-Seq pipelines with interactive report.',
#   'authors': '["Giulio Spinozzi", "Giulio", "Spinozzi", "Maria Paola Martelli", "Maria Paola", "Martelli"]'},
#  {'pmcid': 'ASA3P: An automatic and scalable pipeline for the assembly, annotation and higher-level analysis of closely related bacterial isolates.',
#   'authors': '["Oliver Schwengers", "Oliver", "Schwengers", "Alexander Goesmann", "Alexander", "Goesmann"]'},
#  {'pmcid': 'ASAP: a machine learning framework for local protein properties.',
#   'authors': '["Nadav Brandes", "Nadav", "Brandes", "Michal Linial", "Michal", "Linial"]'},
#  {'pmcid': 'ASaiM: a Galaxy-based framework to analyze microbiota data.',
#   'authors': '["B\\u00e9r\\u00e9nice Batut", "B\\u00e9r\\u00e9nice", "Batut", "Pierre Peyret", "Pierre", "Peyret"]'},
#  {'pmcid': 'Abandoning the Isochore Theory Can Help Explain Genome Compositional Organization in Fish.',
#   'authors': '["Marta Vohnoutov\\u00e1", "Marta", "Vohnoutov\\u00e1", "Radka Symonov\\u00e1", "Radka", "Symonov\\u00e1"]'},
#  {'pmcid': 'Abasy Atlas: a comprehensive inventory of systems, global network properties and systems-level elements across bacteria.',
#   'authors': '["Miguel A Ibarra-Arellano", "Miguel A", "Ibarra-Arellano", "Julio A Freyre-Gonz\\u00e1lez", "Julio A", "Freyre-Gonz\\u00e1lez"]'},
#  {'pmcid': 'Aberrant Cholesterol Metabolic Genes Regulation in a Negative Feedback Loop Induced by an Alphacoronavirus.',
#   'authors': '["Hao-Yu Liu", "Hao-Yu", "Liu", "Demin Cai", "Demin", "Cai"]'},
#  {'pmcid': 'Aberrant alternative splicing of HTR2A exon II in peripheral blood lymphocytes of drug-naïve schizophrenic patients.',
#   'authors': '["Maria N Grunina", "Maria N", "Grunina", "Anna M Zabotina", "Anna M", "Zabotina"]'},
#  {'pmcid': 'Ablation of Perk in Schwann Cells Improves Myelination in the S63del Charcot-Marie-Tooth 1B Mouse.',
#   'authors': '["Mariapaola Sidoli", "Mariapaola", "Sidoli", "Lawrence Wrabetz", "Lawrence", "Wrabetz"]'},
#  {'pmcid': 'Abnormal glucose homeostasis and fasting intolerance in patients with congenital porto-systemic shunts.',
#   'authors': '["Mirjam E van Albada", "Mirjam E", "van Albada", "Hubert P J van der Doef", "Hubert P J", "van der Doef"]'},
#  {'pmcid': 'Accelerated global sensitivity analysis of genome-wide constraint-based metabolic models.',
#   'authors': '["Marco S Nobile", "Marco S", "Nobile", "Chiara Damiani", "Chiara", "Damiani"]'},
#  {'pmcid': 'Accelerated phosphatidylcholine turnover in macrophages promotes adipose tissue inflammation in obesity.',
#   'authors': '["Kasparas Petkevicius", "Kasparas", "Petkevicius", "Antonio Vidal-Puig", "Antonio", "Vidal-Puig"]'},
#  {'pmcid': 'Acceleration of Molecular Simulations by Parametric Time-Lagged tSNE Metadynamics.',
#   'authors': '["Helena Hradisk\\u00e1", "Helena", "Hradisk\\u00e1", "Vojt\\u011bch Spiwok", "Vojt\\u011bch", "Spiwok"]'},
#  {'pmcid': 'Acceptability and usability of a mobile application for management and surveillance of vector-borne diseases in Colombia: An implementation study.',
#   'authors': '["Sarita Rodr\\u00edguez", "Sarita", "Rodr\\u00edguez", "Fernando Rosso", "Fernando", "Rosso"]'},
#  {'pmcid': 'Accessible and reproducible mass spectrometry imaging data analysis in Galaxy.',
#   'authors': '["Melanie Christine F\\u00f6ll", "Melanie Christine", "F\\u00f6ll", "Oliver Schilling", "Oliver", "Schilling"]'},
#  {'pmcid': 'Accounting for ambiguity in ancestral sequence reconstruction.',
#   'authors': '["A Oliva", "A", "Oliva", "S Guindon", "S", "Guindon"]'},
#  {'pmcid': 'Accumulating computational resource usage of genomic data analysis workflow to optimize cloud computing instance selection.',
#   'authors': '["Tazro Ohta", "Tazro", "Ohta", "Osamu Ogasawara", "Osamu", "Ogasawara"]'},
#  {'pmcid': 'Accumulation of retrotransposons contributes to W chromosome differentiation in the willow beauty Peribatodes rhomboidaria (Lepidoptera: Geometridae).',
#   'authors': '["Martina Hejn\\u00ed\\u010dkov\\u00e1", "Martina", "Hejn\\u00ed\\u010dkov\\u00e1", "Eugenia E Montiel", "Eugenia E", "Montiel"]'},
#  {'pmcid': 'Accurate detection and quantification of SARS-CoV-2 genomic and subgenomic mRNAs by ddPCR and meta-transcriptomics analysis.',
#   'authors': '["Annarita Oranger", "Annarita", "Oranger", "Graziano Pesole", "Graziano", "Pesole"]'},
#  {'pmcid': 'Accurate quantification of bacterial abundance in metagenomic DNAs accounting for variable DNA integrity levels.',
#   'authors': '["Caterina Manzari", "Caterina", "Manzari", "Anna Maria D\'Erchia", "Anna Maria", "D\'Erchia"]'},
#  {'pmcid': 'Acetylcholine, Another Factor in Breast Cancer.',
#   'authors': '["Juan P Mu\\u00f1oz", "Juan P", "Mu\\u00f1oz", "Gloria M Calaf", "Gloria M", "Calaf"]'},
#  {'pmcid': 'Achieving human and machine accessibility of cited data in scholarly publications.',
#   'authors': '["Joan Starr", "Joan", "Starr", "Tim Clark", "Tim", "Clark"]'},
#  {'pmcid': 'Acidisoma silvae sp. nov. and Acidisomacellulosilytica sp. nov., Two Acidophilic Bacteria Isolated from Decaying Wood, Hydrolyzing Cellulose and Producing Poly-3-hydroxybutyrate.',
#   'authors': '["Sophie Mieszkin", "Sophie", "Mieszkin", "Karine Alain", "Karine", "Alain"]'},
#  {'pmcid': 'Actionable pathways: interactive discovery of therapeutic targets using signaling pathway models.',
#   'authors': '["Francisco Salavert", "Francisco", "Salavert", "Joaqu\\u00edn Dopazo", "Joaqu\\u00edn", "Dopazo"]'},
#  {'pmcid': 'Activated RNAi does not rescue piRNA pathway deficiency in testes',
#   'authors': '["Eliska Taborska", "Eliska", "Taborska", "Petr Svoboda", "Petr", "Svoboda"]'},
#  {'pmcid': 'Activation performance and mechanism of a novel heterogeneous persulfate catalyst: Metal Organic Framework MIL-53(Fe) with FeII/FeIII mixed-valence coordinative unsaturated iron center.',
#   'authors': '["Mengjie Pu", "Mengjie", "Pu", "Mark L Brusseau", "Mark L", "Brusseau"]'},
#  {'pmcid': 'Acute, Chronic, and Treated Aortic Diseases Present Distinguishable Serum Proteome Fingerprints with Protein Profiles That Correlate with Disease Severity.',
#   'authors': '["Jasmin H Shahinian", "Jasmin H", "Shahinian", "Martin Czerny", "Martin", "Czerny"]'},
#  {'pmcid': 'Adam22 is a major neuronal receptor for Lgi4-mediated Schwann cell signaling.',
#   'authors': '["Ekim Ozkaynak", "Ekim", "Ozkaynak", "Dies Meijer", "Dies", "Meijer"]'},
#  {'pmcid': 'Adaptive Diversity of Beech Seedlings Under Climate Change Scenarios.',
#   'authors': '["Georgios Varsamis", "Georgios", "Varsamis", "Oliver Gailing", "Oliver", "Gailing"]'},
#  {'pmcid': 'Adaptive changes of the autosomal part of the genome in a dioecious clade of Silene.',
#   'authors': '["Jitka Zluvova", "Jitka", "Zluvova", "Bohuslav Janousek", "Bohuslav", "Janousek"]'},
#  {'pmcid': 'Addendum: The FAIR Guiding Principles for scientific data management and stewardship.',
#   'authors': '["Mark D Wilkinson", "Mark D", "Wilkinson", "Barend Mons", "Barend", "Mons"]'},
#  {'pmcid': 'Addressing Beacon re-identification attacks: quantification and mitigation of privacy risks.',
#   'authors': '["Jean Louis Raisaro", "Jean Louis", "Raisaro", "Jean-Pierre Hubaux", "Jean-Pierre", "Hubaux"]'},
#  {'pmcid': 'Adenine base editing efficiently restores the function of Fanconi anemia hematopoietic stem and progenitor cells.',
#   'authors': '["Sebastian M Siegner", "Sebastian M", "Siegner", "Jacob E Corn", "Jacob E", "Corn"]'},
#  {'pmcid': 'Adult-Onset Parkinsonism as Late Manifestation of HIVEP2-Associated Developmental Disorder.',
# ...
#   'authors': '["Ingeborg Scholz", "Ingeborg", "Scholz", "Wolfgang R Hess", "Wolfgang R", "Hess"]'},
#  {'pmcid': 'Diversified regulation of circadian clock gene expression following whole genome duplication.',
#   'authors': '["Alexander C West", "Alexander C", "West", "Shona H Wood", "Shona H", "Wood"]'},
#  {'pmcid': 'Documenting the de-identification process of clinical and imaging data for AI for health imaging projects.',
#   'authors': '["Haridimos Kondylakis", "Haridimos", "Kondylakis", "Manolis Tsiknakis", "Manolis", "Tsiknakis"]'},
#  {'pmcid': 'Does improved oleic acid content due to marker-assisted introgression of ahFAD2 mutant alleles in peanuts alter its mineral and vitamin composition?',
#   'authors': '["Jignesh H Kamdar", "Jignesh H", "Kamdar", "Sandip K Bera", "Sandip K", "Bera"]'},
#  {'pmcid': 'Domain-Specific Common Data Elements for Rare Disease Registration: Conceptual Approach of a European Joint Initiative Toward Semantic Interoperability in Rare Disease Research.',
#   'authors': '["Haitham Abaza", "Haitham", "Abaza", "Holger Storf", "Holger", "Storf"]'},
#  {'pmcid': 'Dominant ARF3 variants disrupt Golgi integrity and cause a neurodevelopmental disorder recapitulated in zebrafish.',
#   'authors': '["Giulia Fasano", "Giulia", "Fasano", "Marco Tartaglia", "Marco", "Tartaglia"]'},
#  {'pmcid': 'Dominant KPNA3 Mutations Cause Infantile-Onset Hereditary Spastic Paraplegia.',
#   'authors': '["Claudia Schob", "Claudia", "Schob", "Jonas Denecke", "Jonas", "Denecke"]'},
#  {'pmcid': 'Dominant VPS16 Pathogenic Variants: Not Only Isolated Dystonia.',
#   'authors': '["Edoardo Monfrini", "Edoardo", "Monfrini", "Alessio Di Fonzo", "Alessio", "Di Fonzo"]'},
#  {'pmcid': 'Dopamine Transporter Deficient Rodents: Perspectives and Limitations for Neuroscience.',
#   'authors': '["Artem Savchenko", "Artem", "Savchenko", "Ilya Sukhanov", "Ilya", "Sukhanov"]'},
#  {'pmcid': 'Dose-dependent consequences of sub-chronic fentanyl exposure on neuron and glial co-cultures.',
#   'authors': '["Doris Lam", "Doris", "Lam", "Heather A Enright", "Heather A", "Enright"]'},
#  {'pmcid': 'Draft Genome Sequence of Pseudomonas aeruginosa Strain WS136, a Highly Cytotoxic ExoS-Positive Wound Isolate Recovered from Pyoderma Gangrenosum.',
#   'authors': '["Martin Arnold", "Martin", "Arnold", "Frank-J\\u00f6rg Vorh\\u00f6lter", "Frank-J\\u00f6rg", "Vorh\\u00f6lter"]'},
#  {'pmcid': 'Draft Genome Sequence of Streptococcus anginosus BVI, a New Vaginal Pathogen Candidate.',
#   'authors': '["Andres Zu\\u00f1iga-Bahamon", "Andres", "Zu\\u00f1iga-Bahamon", "Andreas Tauch", "Andreas", "Tauch"]'},
#  {'pmcid': 'Draft Genome Sequence of the Fruiting Myxobacterium Nannocystis exedens DSM 71.',
#   'authors': '["Anke Treuner-Lange", "Anke", "Treuner-Lange", "Lotte S\\u00f8gaard-Andersen", "Lotte", "S\\u00f8gaard-Andersen"]'},
#  {'pmcid': 'Draft Genome Sequence of the Vaccination Strain Mycobacterium bovis BCG S4-Jena.',
#   'authors': '["Daniel Wibberg", "Daniel", "Wibberg", "J\\u00f6rn Kalinowski", "J\\u00f6rn", "Kalinowski"]'},
#  {'pmcid': 'Draft Genome Sequences of Three Clostridia Isolates Involved in Lactate-Based Chain Elongation.',
#   'authors': '["Bin Liu", "Bin", "Liu", "Sabine Kleinsteuber", "Sabine", "Kleinsteuber"]'},
#  {'pmcid': 'Draft Genome Sequences of Three Novel Staphylococcus arlettae Strains Isolated from a Disused Biological Safety Cabinet.',
#   'authors': '["Anna Lavecchia", "Anna", "Lavecchia", "Antonio Placido", "Antonio", "Placido"]'},
#  {'pmcid': 'Draft Genomes of Two Fusobacterium simiae Strains.',
#   'authors': '["Malak Zoaiter", "Malak", "Zoaiter", "Linda Houhamdi", "Linda", "Houhamdi"]'},
#  {'pmcid': 'Draft Sequencing Crested Wheatgrass Chromosomes Identified Evolutionary Structural Changes and Genes and Facilitated the Development of SSR Markers.',
#   'authors': '["Jana Zwyrtkov\\u00e1", "Jana", "Zwyrtkov\\u00e1", "Eva H\\u0159ibov\\u00e1", "Eva", "H\\u0159ibov\\u00e1"]'},
#  {'pmcid': 'Draft genome sequence of Amycolatopsis camponoti RTGN1, a bacterial endophyte isolated from Alnus glutinosa root nodules.',
#   'authors': '["Ryan Michael Thompson", "Ryan Michael", "Thompson", "Maria Del Carmen Montero-Calasanz", "Maria Del Carmen", "Montero-Calasanz"]'},
#  {'pmcid': 'Draft genome sequence of Kocuria indica DP-K7, a methyl red degrading actinobacterium.',
#   'authors': '["Selvapravin Kumaran", "Selvapravin", "Kumaran", "Dirk Tischler", "Dirk", "Tischler"]'},
#  {'pmcid': 'Draft genome sequence of Promicromonospora panici sp. nov., a novel ionizing-radiation-resistant actinobacterium isolated from roots of the desert plant Panicum turgidum.',
#   'authors': '["Sihem Guesmi", "Sihem", "Guesmi", "Philippe Normand", "Philippe", "Normand"]'},
#  {'pmcid': 'Draft genome sequence of Streptomyces poriferorum RTGN2, a bacterial endophyte isolated from Alnus glutinosa root nodules.',
#   'authors': '["Ryan Michael Thompson", "Ryan Michael", "Thompson", "Maria Del Carmen Montero-Calasanz", "Maria Del Carmen", "Montero-Calasanz"]'},
#  {'pmcid': 'Draft genome sequence of pectic polysaccharide-degrading moderate thermophilic bacterium Geobacillus thermodenitrificans DSM 101594.',
#   'authors': '["Raimonda Petkauskaite", "Raimonda", "Petkauskaite", "Nomeda Kuisiene", "Nomeda", "Kuisiene"]'},
#  {'pmcid': 'Draft genome sequences of five Mycobacterium strains, isolated from Alnus glutinosa root nodules.',
#   'authors': '["Ryan Michael Thompson", "Ryan Michael", "Thompson", "Maria Del Carmen Montero-Calasanz", "Maria Del Carmen", "Montero-Calasanz"]'},
#  {'pmcid': 'Draft genome sequences of three Xanthomonas translucens pathovar reference strains (pv. arrhenatheri, pv. poae and pv. phlei) with different specificities for forage grasses.',
#   'authors': '["Lena Hersemann", "Lena", "Hersemann", "Roland K\\u00f6lliker", "Roland", "K\\u00f6lliker"]'},
#  {'pmcid': 'Draft genome sequences of two Micromonospora strains isolated from the root nodules of Alnus glutinosa.',
#   'authors': '["Ryan Michael Thompson", "Ryan Michael", "Thompson", "Maria Del Carmen Montero-Calasanz", "Maria Del Carmen", "Montero-Calasanz"]'},
#  {'pmcid': 'Droplet digital PCR for fast and accurate characterization of NF1 locus deletions: confirmation of the predominant maternal origin of type-1 deletions.',
#   'authors': '["Laurence Pacot", "Laurence", "Pacot", "Eric Pasmant", "Eric", "Pasmant"]'},
#  {'pmcid': 'Drug Repurposing Screen to Identify Inhibitors of Sars-Cov-2 Minimal Functional Replication and Transcription Complex',
#   'authors': '["Maria Kuzikov", "Maria", "Kuzikov", "Andrea Zaliani", "Andrea", "Zaliani"]'},
#  {'pmcid': 'Drug repurposing for COVID-19 using machine learning and mechanistic models of signal transduction circuits related to SARS-CoV-2 infection.',
#   'authors': '["Carlos Loucera", "Carlos", "Loucera", "Mar\\u00eda Pe\\u00f1a-Chilet", "Mar\\u00eda", "Pe\\u00f1a-Chilet"]'},
#  {'pmcid': 'Drug repurposing for rare: progress and opportunities for the rare disease community.',
#   'authors': '["Anneliene Hechtelt Jonker", "Anneliene Hechtelt", "Jonker", "Anna Maria Gerdina Pasmooij", "Anna Maria Gerdina", "Pasmooij"]'},
#  {'pmcid': 'Drug repurposing screen to identify inhibitors of the RNA polymerase (nsp12) and helicase (nsp13) from SARS-CoV-2 replication and transcription complex.',
#   'authors': '["Maria Kuzikov", "Maria", "Kuzikov", "Andrea Zaliani", "Andrea", "Zaliani"]'},
#  {'pmcid': 'Drug review process advancement and required manufacturer and contract research oraganization responses.',
#   'authors': '["Takayuki Anzai", "Takayuki", "Anzai", "Takaaki Matsuyama", "Takaaki", "Matsuyama"]'},
#  {'pmcid': 'DrugComb update: a more comprehensive drug sensitivity data repository and analysis portal',
#   'authors': '["Shuyu Zheng", "Shuyu", "Zheng", "Jing Tang", "Jing", "Tang"]'},
#  {'pmcid': 'DrugComb update: a more comprehensive drug sensitivity data repository and analysis portal.',
#   'authors': '["Shuyu Zheng", "Shuyu", "Zheng", "Jing Tang", "Jing", "Tang"]'},
#  {'pmcid': 'DrugComb: an integrative cancer drug combination data portal.',
#   'authors': '["Bulat Zagidullin", "Bulat", "Zagidullin", "Jing Tang", "Jing", "Tang"]'},
#  {'pmcid': 'DrugRepo: a novel approach to repurposing drugs based on chemical and genomic features.',
#   'authors': '["Yinyin Wang", "Yinyin", "Wang", "Ziaurrehman Tanoli", "Ziaurrehman", "Tanoli"]'},
#  {'pmcid': 'Dynamic flows create potentially habitable conditions in Antarctic subglacial lakes.',
#   'authors': '["Louis-Alexandre Couston", "Louis-Alexandre", "Couston", "Martin Siegert", "Martin", "Siegert"]'},
#  {'pmcid': 'Dynamic inosinome profiles reveal novel patient stratification and gender-specific differences in glioblastoma.',
#   'authors': '["Domenico Alessandro Silvestris", "Domenico Alessandro", "Silvestris", "Angela Gallo", "Angela", "Gallo"]'},
#  {'pmcid': 'Dynamic microfluidic single-cell screening identifies pheno-tuning compounds to potentiate tuberculosis therapy.',
#   'authors': '["Maxime Mistretta", "Maxime", "Mistretta", "Giulia Manina", "Giulia", "Manina"]'},
#  {'pmcid': 'Dynamics of a Protein Interaction Network Associated to the Aggregation of polyQ-Expanded Ataxin-1.',
#   'authors': '["Aimilia-Christina Vagiona", "Aimilia-Christina", "Vagiona", "Spyros Petrakis", "Spyros", "Petrakis"]'},
#  {'pmcid': 'Dystonia Linked to EIF4A2 Haploinsufficiency: A Disorder of Protein Translation Dysfunction.',
#   'authors': '["Philip Harrer", "Philip", "Harrer", "Michael Zech", "Michael", "Zech"]'},
#  {'pmcid': 'Dystonia and mitochondrial disease: the movement disorder connection revisited in 900 genetically diagnosed patients.',
#   'authors': '["Elisabetta Indelicato", "Elisabetta", "Indelicato", "Michael Zech", "Michael", "Zech"]'},
#  {'pmcid': 'Dystrophin deficiency impairs cell junction formation during embryonic myogenesis from pluripotent stem cells.',
#   'authors': '["Elise Mozin", "Elise", "Mozin", "Jean-Baptiste Dupont", "Jean-Baptiste", "Dupont"]'},
#  {'pmcid': 'E-Science technologies in a workflow for personalized medicine using cancer screening as a case study.',
#   'authors': '["Ola Spjuth", "Ola", "Spjuth", "Juni Palmgren", "Juni", "Palmgren"]'},
#  {'pmcid': 'EBI Metagenomics in 2017: enriching the analysis of microbial communities, from sequence reads to assemblies.',
#   'authors': '["Alex L Mitchell", "Alex L", "Mitchell", "Robert D Finn", "Robert D", "Finn"]'},
#  {'pmcid': 'ECCB2022: the 21st European Conference on Computational Biology.',
#   'authors': '["Salvador Capella-Gutierrez", "Salvador", "Capella-Gutierrez", "Alfonso Valencia", "Alfonso", "Valencia"]'},
#  {'pmcid': 'ECO: the Evidence and Conclusion Ontology, an update for 2022.',
#   'authors': '["Suvarna Nadendla", "Suvarna", "Nadendla", "Michelle G Giglio", "Michelle G", "Giglio"]'},
#  {'pmcid': 'ECRIN - CESSDA strategies for cross metadata mappings in selected areas between life sciences and social sciences and humanities.',
#   'authors': '["Christian Ohmann", "Christian", "Ohmann", "Maria Panagiotopoulou", "Maria", "Panagiotopoulou"]'},
#  {'pmcid': 'EDAM: an ontology of bioinformatics operations, types of data and identifiers, topics and formats.',
#   'authors': '["Jon Ison", "Jon", "Ison", "Peter Rice", "Peter", "Rice"]'},
#  {'pmcid': 'EDGAR 2.0: an enhanced software platform for comparative gene content analyses.',
#   'authors': '["Jochen Blom", "Jochen", "Blom", "Alexander Goesmann", "Alexander", "Goesmann"]'},
#  {'pmcid': 'ELIXIR Software Management Plan for Life Sciences',
#   'authors': '["Renato Alves", "Renato", "Alves", "Allegra Via", "Allegra", "Via"]'},
#  {'pmcid': 'ELIXIR and Toxicology: a community in development.',
#   'authors': '["Marvin Martens", "Marvin", "Martens", "Egon L Willighagen", "Egon L", "Willighagen"]'},
#  {'pmcid': 'ELIXIR biovalidator for semantic validation of life science metadata.',
#   'authors': '["Isuru Liyanage", "Isuru", "Liyanage", "Frederik Coppens", "Frederik", "Coppens"]'},
#  {'pmcid': 'ELIXIR pilot action: Marine metagenomics - towards a domain specific set of sustainable services.',
#   'authors': '["Espen Mikal Robertsen", "Espen Mikal", "Robertsen", "Nils Peder Willassen", "Nils Peder", "Willassen"]'},
#  {'pmcid': 'ELIXIR pilot action: Marine metagenomics – towards a domain specific set of sustainable services',
#   'authors': '["Espen Mikal Robertsen", "Espen Mikal", "Robertsen", "Nils Peder Willassen", "Nils Peder", "Willassen"]'},
#  {'pmcid': "ELIXIR-EXCELERATE: establishing Europe's data infrastructure for the life science research of the future.",
#   'authors': '["Jennifer Harrow", "Jennifer", "Harrow", "Niklas Blomberg", "Niklas", "Blomberg"]'},
#  {'pmcid': 'ELIXIR-IT HPC@CINECA: high performance computing resources for the bioinformatics community.',
#   'authors': '["Tiziana Castrignan\\u00f2", "Tiziana", "Castrignan\\u00f2", "Federico Zambelli", "Federico", "Zambelli"]'},
#  {'pmcid': 'ELIXIR-UK role in bioinformatics training at the national level and across ELIXIR.',
#   'authors': '["L Larcombe", "L", "Larcombe", "G Rustici", "G", "Rustici"]'},
#  {'pmcid': 'ELIXIR: Providing a Sustainable Infrastructure for Life Science Data at European Scale.',
#   'authors': '["Jennifer Harrow", "Jennifer", "Harrow", "Niklas Blomberg", "Niklas", "Blomberg"]'},
#  {'pmcid': "EMBL's European Bioinformatics Institute (EMBL-EBI) in 2022.",
#   'authors': '["Matthew Thakur", "Matthew", "Thakur", "Johanna McEntyre", "Johanna", "McEntyre"]'},
#  {'pmcid': "EMBL's European Bioinformatics Institute (EMBL-EBI) in 2023.",
#   'authors': '["Matthew Thakur", "Matthew", "Thakur", "Johanna McEntyre", "Johanna", "McEntyre"]'},
#  {'pmcid': 'EMDB Web Resources.',
#   'authors': '["Sanja Abbott", "Sanja", "Abbott", "Ardan Patwardhan", "Ardan", "Patwardhan"]'},
#  {'pmcid': 'EMDataBank unified data resource for 3DEM.',
#   'authors': '["Catherine L Lawson", "Catherine L", "Lawson", "Wah Chiu", "Wah", "Chiu"]'},
#  {'pmcid': 'ENA Source Attribute Helper: An Application Programming Interface to facilitate accurate reference to biological source data',
#   'authors': '["Vikas Gupta", "Vikas", "Gupta", "Guy Cochrane", "Guy", "Cochrane"]'},
#  {'pmcid': 'EOSC Future: Design and implementation of community engagement through Science Projects',
#   'authors': '["Christos Arvanitidis", "Christos", "Arvanitidis", "Sophie Viscido", "Sophie", "Viscido"]'},
#  {'pmcid': 'ESCAPE Dark Matter Science Project for EOSC Future project (WP6.3)',
#   'authors': '["Pooja Bhattacharjee", "Pooja", "Bhattacharjee", "Mikhail Smirnov", "Mikhail", "Smirnov"]'},
#  {'pmcid': 'EU funds absorption for Romanian rural municipalities: a spatial distribution',
#   'authors': '["Anca Monica Marin", "Anca Monica", "Marin", "Bogdan Corad", "Bogdan", "Corad"]'},
#  {'pmcid': 'EURO-NMD registry: federated FAIR infrastructure, innovative technologies and concepts of a patient-centred registry for rare neuromuscular disorders.',
#   'authors': '["Antonio Atalaia", "Antonio", "Atalaia", "Teresinha Evangelista", "Teresinha", "Evangelista"]'},
#  {'pmcid': 'Early DNA methylation changes in children developing beta cell autoimmunity at a young age.',
#   'authors': '["Inna Starskaia", "Inna", "Starskaia", "Riitta Lahesmaa", "Riitta", "Lahesmaa"]'},
#  {'pmcid': 'Early Response of Sulfolobus acidocaldarius to Nutrient Limitation.',
#   'authors': '["Lisa F Bischof", "Lisa F", "Bischof", "Sonja-Verena Albers", "Sonja-Verena", "Albers"]'},
#  {'pmcid': 'EasyDock: customizable and scalable docking tool.',
#   'authors': '["Guzel Minibaeva", "Guzel", "Minibaeva", "Pavel Polishchuk", "Pavel", "Polishchuk"]'},
#  {'pmcid': 'Economic Genome Assembly from Low Coverage Illumina and Nanopore Data',
#   'authors': '["Thomas Gatter", "Thomas", "Gatter", "Peter Stadler", "Peter", "Stadler"]'},
#  {'pmcid': 'Ectopic germinal centers in the thymus accurately predict prognosis of myasthenia gravis after thymectomy.',
#   'authors': '["Joona Sarkkinen", "Joona", "Sarkkinen", "Sini M Laakso", "Sini M", "Laakso"]'},
#  {'pmcid': 'Editorial on Machine Learning, AI and Big Data Methods and Findings for COVID-19.',
#   'authors': '["Victor Chang", "Victor", "Chang", "Reinhold Behringer", "Reinhold", "Behringer"]'},
#  ...]

# %%
articles_full_authors
# Out:
# Index(['Article Title', 'source', 'pmid', 'pmcid', 'doi_df1', 'title',
#        'authorString', 'first_author_firstName', 'first_author_lastName',
#        'last_author_firstName', 'last_author_lastName', 'abstractText',
#        'printPublicationDate', 'journal_title_df1', 'affiliation', 'keywords',
#        'meshHeadings', 'mod_title', 'Year', 'journal_title_df2', 'doi_df2',
#        'Source', 'empty', 'final_doi'],
#       dtype='object')

# %%
unique_fauthors = set(articles_full_authors['first_author'].unique())
unique_lauthors = set(articles_full_authors['last_author'].unique())

unique_authors = unique_fauthors.union(unique_lauthors)

# %%
print(f"Amount of unique first authors: {len(unique_fauthors)}")
print(f"Amount of unique last authors: {len(unique_lauthors)}")
print(f"Amount of unique authors: {len(unique_authors)}")
# Out:
# Amount of unique first authors: 2494
# Amount of unique last authors: 1997
# Amount of unique authors: 4289

# %%
unique_fauthors_fnames = set(articles_full_authors['first_author_firstName'].unique())
unique_lauthors_fnames = set(articles_full_authors['last_author_firstName'].unique())

unique_authors_fnames = unique_fauthors_fnames.union(unique_lauthors_fnames)

# %%
print(f"Amount of unique first authors' first names: {len(unique_fauthors_fnames)}")
print(f"Amount of unique last authors' first names: {len(unique_lauthors_fnames)}")
print(f"Amount of unique authors' first names: {len(unique_authors_fnames)}")
# Out:
# Amount of unique first authors' first names: 1822
# Amount of unique last authors' first names: 1457
# Amount of unique authors' first names: 2800

# %% [markdown]
# So we have gathered the information from papers that have all of the author information. Let's start here with the GenderTracker predictions.

# %% [markdown]
# Information of papers having at least info about the first or last author names:

# %%
articles_some_authors_names = pd.concat([articles_first_authors_all, articles_last_authors_all])
articles_some_authors_names = articles_some_authors_names.reset_index().drop(columns='index')

# %%
articles_some_authors_names
# Out:
#                                          Article Title source  \
# 0    3Rs toxicity testing and disease modeling proj...    MED
# 1    A benchmark of optimization solvers for genome...    MED
# 2    A recent origin of Orf3a from M protein across...    MED
# 3    A survey into the contribution of regional/nat...    PPR
# 4    A versatile and interoperable computational fr...    PPR
# ..                                                 ...    ...
# 106  htsget: a protocol for securely streaming geno...    MED
# 107  Mental health impact of the first wave of COVI...    MED
# 108  The Dutch Techcentre for Life Sciences: Enabli...    PPR
# 109  Capturing variation impact on molecular intera...    MED
# 110  No more business as usual: agile and effective...    PPR
#
#                         pmid                     pmcid  \
# 0                 32636731.0                PMC7332811
# 1                 38251879.0               PMC10878033
# 2                 33363705.0                PMC7749296
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ..                       ...                       ...
# 106               29931085.0                PMC6298043
# 107  34127211.0 | 33309957.0  PMC10068024 | PMC7726524
# 108                      NaN                       NaN
# 109               30602777.0                PMC6315030
# 110                      NaN                       NaN
#
#                                                doi_df1  \
# 0                              10.17179/excli2020-1463
# 1                            10.1128/msystems.00833-23
# 2                           10.1016/j.csbj.2020.11.047
# 3                      10.12688/f1000research.142165.1
# 4                            10.1101/2022.12.17.520865
# ..                                                 ...
# 106                      10.1093/bioinformatics/bty492
# 107  10.1016/j.rpsmen.2021.05.003 | 10.1016/j.rpsm....
# 108                      10.12688/f1000research.6009.2
# 109                         10.1038/s41467-018-07709-6
# 110                          10.1101/2020.02.21.959973
#
#                                                  title  \
# 0    3Rs toxicity testing and disease modeling proj...
# 1    A benchmark of optimization solvers for genome...
# 2    A recent origin of Orf3a from M protein across...
# 3    A survey into the contribution of regional/nat...
# 4    A versatile and interoperable computational fr...
# ..                                                 ...
# 106  htsget: a protocol for securely streaming geno...
# 107  Mental health impact of the first wave of COVI...
# 108  The Dutch Techcentre for Life Sciences: Enabli...
# 109  Capturing variation impact on molecular intera...
# 110  No more business as usual: agile and effective...
#
#                                           authorString first_author_firstName  \
# 0                                            Vinken M.                Mathieu
# 1                                           Machado D.                 Daniel
# 2                                         Ouzounis CA.             Christos A
# 3    Neves A, Willassen NP, Hjerde E, Cuesta I, Mar...                 Aitana
# 4    Niarakis A, Ostaszewski M, Mazein A, Kuperstei...                   Anna
# ..                                                 ...                    ...
# 106  Kelleher J, Lin M, Albach CH, Birney E, Davies...                 Jerome
# 107  Alonso J, Vilagut G, Mortier P, Ferrer M, Alay...                  Jordi
# 108  Eijssen L, Evelo CT, Kok R, Mons B, Hooft RW, ...                   Lars
# 109  IMEx Consortium Curators, Del-Toro N, Duesbury...                    NaN
# 110  Galaxy and HyPhy developments teams, Nekrutenk...                    NaN
#
#     first_author_lastName last_author_firstName last_author_lastName  \
# 0                  Vinken                   NaN                  NaN
# 1                 Machado                   NaN                  NaN
# 2                Ouzounis                   NaN                  NaN
# 3                   Neves                   NaN                  NaN
# 4                Niarakis                   NaN                  NaN
# ..                    ...                   ...                  ...
# 106              Kelleher                   NaN                  NaN
# 107                Alonso                   NaN                  NaN
# 108               Eijssen                   NaN                  NaN
# 109                   NaN                     P               Porras
# 110                   NaN                Sergei      Kosakovsky Pond
#
#                                           abstractText printPublicationDate  \
# 0    The 3Rs concept, calling for replacement, redu...           2020-01-01
# 1    Genome-scale metabolic modeling is a powerful ...           2024-02-01
# 2    The genome of SARS-CoV-2, the coronavirus resp...           2020-01-01
# 3    Background:  Regional/national SARS-CoV-2 geno...                  NaN
# 4    The COVID-19 Disease Map project is a large-sc...                  NaN
# ..                                                 ...                  ...
# 106  SummaryStandardized interfaces for efficiently...           2019-01-01
# 107  IntroductionHealthcare workers are vulnerable ...           2021-04-01
# 108  We describe the Data programme of the Dutch Te...                  NaN
# 109  The current wealth of genomic variation data i...           2019-01-01
# 110  The current state of much of the Wuhan pneumon...                  NaN
#
#                                      journal_title_df1  \
# 0                                        EXCLI journal
# 1                                             mSystems
# 2    Computational and structural biotechnology jou...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 106                   Bioinformatics (Oxford, England)
# 107              Revista de psiquiatria y salud mental
# 108                                                NaN
# 109                              Nature communications
# 110                                                NaN
#
#                                            affiliation  \
# 0    Department of In Vitro Toxicology and Dermato-...
# 1    Department of Biotechnology and Food Science, ...
# 2    Biological Computation & Process Laboratory (B...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 106  Big Data Institute, Li Ka Shing Centre for Hea...
# 107  Health Services Research Unit, IMIM-Institut H...
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
#
#                                               keywords  \
# 0    In vitro, In silico, Europe, 3Rs, Horizon 2020...
# 1    Metabolism, Genome-scale Modeling, Optimizatio...
# 2    Protein superfamily, Structure prediction, M p...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 106                                                NaN
# 107  Mental disorders, Disability, Healthcare Worke...
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
#
#                                           meshHeadings  \
# 0                                                  NaN
# 1    Humans, Ecosystem, Biochemical Phenomena, Geno...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 106  Computational Biology, Genomics, Genome, Softw...
# 107  Humans, Occupational Diseases, Prevalence, Cro...
# 108                                                NaN
# 109  Animals, Humans, Disease, Amino Acid Substitut...
# 110                                                NaN
#
#                                              mod_title         Year  \
# 0    3RSTOXICITYTESTINGANDDISEASEMODELINGPROJECTSIN...         2020
# 1    ABENCHMARKOFOPTIMIZATIONSOLVERSFORGENOME-SCALE...         2024
# 2    ARECENTORIGINOFORF3AFROMMPROTEINACROSSTHECORON...         2020
# 3    ASURVEYINTOTHECONTRIBUTIONOFREGIONAL/NATIONALP...         2023
# 4    AVERSATILEANDINTEROPERABLECOMPUTATIONALFRAMEWO...         2022
# ..                                                 ...          ...
# 106   HTSGET:APROTOCOLFORSECURELYSTREAMINGGENOMICDATA.         2019
# 107  MENTALHEALTHIMPACTOFTHEFIRSTWAVEOFCOVID-19PAND...  2021 | 2020
# 108  THEDUTCHTECHCENTREFORLIFESCIENCES:ENABLINGDATA...  2015 | 2016
# 109  CAPTURINGVARIATIONIMPACTONMOLECULARINTERACTION...         2019
# 110  NOMOREBUSINESSASUSUAL:AGILEANDEFFECTIVERESPONS...         2020
#
#                                      journal_title_df2  \
# 0                                        EXCLI journal
# 1                                             mSystems
# 2    Computational and structural biotechnology jou...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 106                   Bioinformatics (Oxford, England)
# 107              Revista de psiquiatria y salud mental
# 108                                                NaN
# 109                              Nature communications
# 110                                                NaN
#
#                                                doi_df2 Source  empty  \
# 0                              10.17179/excli2020-1463    MED    NaN
# 1                            10.1128/msystems.00833-23    MED    NaN
# 2                           10.1016/j.csbj.2020.11.047    MED    NaN
# 3                      10.12688/f1000research.142165.1    PPR    NaN
# 4                            10.1101/2022.12.17.520865    PPR    NaN
# ..                                                 ...    ...    ...
# 106                                                NaN    MED    NaN
# 107  10.1016/j.rpsmen.2021.05.003 | 10.1016/j.rpsm....    MED    NaN
# 108                      10.12688/f1000research.6009.2    PPR    NaN
# 109                         10.1038/s41467-018-07709-6    MED    NaN
# 110                          10.1101/2020.02.21.959973    PPR    NaN
#
#                                              final_doi         first_author  \
# 0                              10.17179/excli2020-1463       Mathieu Vinken
# 1                            10.1128/msystems.00833-23       Daniel Machado
# 2                           10.1016/j.csbj.2020.11.047  Christos A Ouzounis
# 3                      10.12688/f1000research.142165.1         Aitana Neves
# 4                            10.1101/2022.12.17.520865        Anna Niarakis
# ..                                                 ...                  ...
# 106                      10.1093/bioinformatics/bty492      Jerome Kelleher
# 107  10.1016/j.rpsmen.2021.05.003 | 10.1016/j.rpsm....         Jordi Alonso
# 108                      10.12688/f1000research.6009.2         Lars Eijssen
# 109                         10.1038/s41467-018-07709-6                  NaN
# 110                          10.1101/2020.02.21.959973                  NaN
#
#                 last_author
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 106                     NaN
# 107                     NaN
# 108                     NaN
# 109                P Porras
# 110  Sergei Kosakovsky Pond
#
# [111 rows x 26 columns]

# %%
csv_to_json_format(input_table = articles_some_authors_names, output_json = 'ea_papers_author_names_data.json')

# %%
with open('ea_papers_author_names_data.json', 'r', encoding='utf-8') as jf:
    ea_papers_author_names_data = json.load(jf)

# %%
ea_papers_author_names_data[0]
# Out:
# {'pmcid': '3Rs toxicity testing and disease modeling projects in the European Horizon 2020 research and innovation program.',
#  'authors': '["Mathieu Vinken", "Mathieu", "Vinken", "NaN", "NaN", "NaN"]'}

# %%
```bash
python genderTracker.py -j authors.json -od results -v True
```
