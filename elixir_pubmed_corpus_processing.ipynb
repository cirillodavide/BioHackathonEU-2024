# %%
import os, sys
import pandas as pd
import json
import numpy as np

# %%
# Pandas configuration to show Dataframes
pd.set_option("display.max_columns", None)     # Show all columns

# %% [markdown]
# ## Analyzing ELIXIR corpus

# %%
ea_papers = '../data/enriched_aggregated_papers.csv'

# %%
ea_papers_df = pd.read_table(ea_papers, encoding='utf-8')

# %%
ordered_articles_ea = ea_papers_df.sort_values(by='Article Title')['Article Title'].tolist()

# %%
ea_papers_df.columns
# Out:
# Index(['Article Title', 'source', 'pmid', 'pmcid', 'doi_df1', 'title',
#        'authorString', 'first_author_firstName', 'first_author_lastName',
#        'last_author_firstName', 'last_author_lastName', 'abstractText',
#        'printPublicationDate', 'journal_title_df1', 'affiliation', 'keywords',
#        'meshHeadings', 'mod_title', 'Year', 'journal_title_df2', 'doi_df2',
#        'Source', 'empty', 'final_doi'],
#       dtype='object')

# %%
# check for NaN or duplicated article titles
print(f"Amount of NaN article titles: {len(ea_papers_df[ea_papers_df['Article Title'].isna()])}")
print(f"Amount of duplicated article titles: {len(ea_papers_df[ea_papers_df['Article Title'].duplicated()])}")
# Out:
# Amount of NaN article titles: 0
# Amount of duplicated article titles: 0

# %%
# check for missing PMCIDs (after checking the code of GenderTracker)
print(f"Amount of articles with unknown PMCIDs: {len(ea_papers_df[ea_papers_df['pmcid'].isna()])}")
# Out:
# Amount of articles with unknown PMCIDs: 651

# %% [markdown]
# That's not very encouraging - the GenderTracker script uses PMCID as the main key to identify the article. However, we will test by putting the article title instead in order for us to not miss so much data in our gender predictions.

# %%
ea_papers_df['first_author'] = ea_papers_df['first_author_firstName'] + ' ' + ea_papers_df['first_author_lastName']
ea_papers_df['last_author'] = ea_papers_df['last_author_firstName'] + ' ' + ea_papers_df['last_author_lastName']

# %%
articles_full_authors = ea_papers_df[
    ea_papers_df['first_author_firstName'].notna() &
    ea_papers_df['first_author_lastName'].notna() &
    ea_papers_df['last_author_firstName'].notna() &
    ea_papers_df['last_author_lastName'].notna()
]

articles_first_authors_all = ea_papers_df[
    ea_papers_df['first_author_firstName'].notna() &
    ea_papers_df['first_author_lastName'].notna() &
    ea_papers_df['last_author_firstName'].isna() &
    ea_papers_df['last_author_lastName'].isna()
]

articles_first_authors_name = ea_papers_df[
    ea_papers_df['first_author_firstName'].notna() &
    ea_papers_df['first_author_lastName'].isna() &
    ea_papers_df['last_author_firstName'].isna() &
    ea_papers_df['last_author_lastName'].isna()
]

articles_first_authors_surname = ea_papers_df[
    ea_papers_df['first_author_firstName'].isna() &
    ea_papers_df['first_author_lastName'].notna() &
    ea_papers_df['last_author_firstName'].isna() &
    ea_papers_df['last_author_lastName'].isna()
]

articles_last_authors_all = ea_papers_df[
    ea_papers_df['first_author_firstName'].isna() &
    ea_papers_df['first_author_lastName'].isna() &
    ea_papers_df['last_author_firstName'].notna() &
    ea_papers_df['last_author_lastName'].notna()
]

articles_last_authors_name = ea_papers_df[
    ea_papers_df['first_author_firstName'].isna() &
    ea_papers_df['first_author_lastName'].isna() &
    ea_papers_df['last_author_firstName'].notna() &
    ea_papers_df['last_author_lastName'].isna()
]

articles_last_authors_surname = ea_papers_df[
    ea_papers_df['first_author_firstName'].isna() &
    ea_papers_df['first_author_lastName'].isna() &
    ea_papers_df['last_author_firstName'].isna() &
    ea_papers_df['last_author_lastName'].notna()
]

articles_none_authors = ea_papers_df[
    ea_papers_df['first_author_firstName'].isna() &
    ea_papers_df['first_author_lastName'].isna() &
    ea_papers_df['last_author_firstName'].isna() &
    ea_papers_df['last_author_lastName'].isna()
]

# %%
print(f"Papers with full author info: {len(articles_full_authors)}")
print(f"Papers with full first author info: {len(articles_first_authors_all)}")
print(f"Papers with name only first author info: {len(articles_first_authors_name)}")
print(f"Papers with surname only first author info: {len(articles_first_authors_surname)}")
print(f"Papers with full last author info: {len(articles_last_authors_all)}")
print(f"Papers with name only last author info: {len(articles_last_authors_name)}")
print(f"Papers with surname only last author info: {len(articles_last_authors_surname)}")
print(f"Papers with none author info: {len(articles_none_authors)}")
# Out:
# Papers with full author info: 3054
# Papers with full first author info: 109
# Papers with name only first author info: 0
# Papers with surname only first author info: 1
# Papers with full last author info: 2
# Papers with name only last author info: 0
# Papers with surname only last author info: 0
# Papers with none author info: 225

# %% [markdown]
# Most papers have information about all the authors. Let's first work with these ones as input to **GenderTracker** and see what it predicts.

# %% [markdown]
# 1) The first step is to convert the CSV to JSON format required by GenderTracker:

# %%
def csv_to_json_format(input_table, output_json: str) -> None:
    
    # Read the CSV file
    if type(input_table)==str: 
        df = pd.read_csv(input_table)
    elif isinstance(input_table, pd.DataFrame):
        df = input_table

    # Prepare the list for JSON data
    json_data = []

    # Iterate over each row to create the desired JSON structure
    for _, row in df.iterrows():
        # Extract relevant fields
        pmcid = row['Article Title']
        first_author_first_name = row['first_author_firstName']
        first_author_last_name = row['first_author_lastName']
        last_author_first_name = row['last_author_firstName']
        last_author_last_name = row['last_author_lastName']

        # Construct the full names of authors
        authors = []
        if pd.notna(first_author_first_name) and pd.notna(first_author_last_name):
            first_author = f"{first_author_first_name} {first_author_last_name}"
            authors.append(first_author)
            authors.append(first_author_first_name)
            authors.append(first_author_last_name)
        else:
            authors.append("NaN")
            authors.append("NaN")
            authors.append("NaN")
            
        if pd.notna(last_author_first_name) and pd.notna(last_author_last_name):
            last_author = f"{last_author_first_name} {last_author_last_name}"
            authors.append(last_author)
            authors.append(last_author_first_name)
            authors.append(last_author_last_name)
        else:
            authors.append("NaN")
            authors.append("NaN")
            authors.append("NaN")

        # Format authors list as JSON string
        authors_json_str = json.dumps(authors)

        # Append the data in the required format
        json_data.append({
            "pmcid": pmcid,
            "authors": authors_json_str
        })

    # Write to output JSON file with proper encoding
    with open(output_json, 'w', encoding='utf-8') as json_file:
        json.dump(json_data, json_file, ensure_ascii=False, indent=4)

# %%
ea_papers_df
# Out:
#                                           Article Title     source  \
# 0     0s and 1s in marine molecular research: a regi...        MED
# 1     1,4-Disubstituted 1H-1,2,3-Triazole Containing...        MED
# 2     10th Anniversary of the European Association f...        NaN
# 3     10th European Conference on Rare Diseases & Or...        MED
# 4     1H, 13C and 15N assignment of the human mitoch...        NaN
# ...                                                 ...        ...
# 3392  The Dutch Techcentre for Life Sciences: Enabli...        PPR
# 3393  The ELIXIR Biodiversity Community: Understandi...        PPR
# 3394                The ELIXIR channel in F1000Research        PPR
# 3395  The need for standardisation in life science r...  MED | PPR
# 3396  Transformer-based tool recommendation system i...        PPR
#
#             pmid       pmcid                          doi_df1  \
# 0     34405237.0  PMC8371273      10.1093/gigascience/giab053
# 1     30972322.0  PMC6443886         10.3389/fchem.2019.00155
# 2            NaN         NaN                              NaN
# 3     33168048.0  PMC7649705       10.1186/s13023-020-01550-1
# 4            NaN         NaN                              NaN
# ...          ...         ...                              ...
# 3392         NaN         NaN    10.12688/f1000research.6009.2
# 3393         NaN         NaN  10.12688/f1000research.133724.2
# 3394         NaN         NaN    10.12688/f1000research.7587.2
# 3395  33604028.0  PMC7863991   10.12688/f1000research.27500.2
# 3396         NaN         NaN        10.1101/2022.12.16.520746
#
#                                                   title  \
# 0     0s and 1s in marine molecular research: a regi...
# 1     1,4-Disubstituted 1H-1,2,3-Triazole Containing...
# 2                                                   NaN
# 3     10th European Conference on Rare Diseases & Or...
# 4                                                   NaN
# ...                                                 ...
# 3392  The Dutch Techcentre for Life Sciences: Enabli...
# 3393  The ELIXIR Biodiversity Community: Understandi...
# 3394                The ELIXIR channel in F1000Research
# 3395  The need for standardisation in life science r...
# 3396  Transformer-based tool recommendation system i...
#
#                                            authorString  \
# 0     Zafeiropoulos H, Gioti A, Ninidakis S, Potirak...
# 1     Schröder DC, Kracker O, Fröhr T, Góra J, Jewgi...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3392  Eijssen L, Evelo CT, Kok R, Mons B, Hooft RW, ...
# 3393  Waterhouse RM, Adam-Blondon A, Balech B, Barta...
# 3394  Blomberg N, Oliveira A, Mons B, Persson B, Jon...
# 3395  Hollmann S, Kremer A, Baebler Š, Trefois C, Gr...
# 3396                    Kumar A, Grüning B, Backofen R.
#
#      first_author_firstName first_author_lastName last_author_firstName  \
# 0                     Haris         Zafeiropoulos             Evangelos
# 1                   David C              Schröder               Norbert
# 2                       NaN                   NaN                   NaN
# 3                       NaN                   NaN                   NaN
# 4                       NaN                   NaN                   NaN
# ...                     ...                   ...                   ...
# 3392                   Lars               Eijssen                   NaN
# 3393                 Robert            Waterhouse                  Toni
# 3394                 Niklas              Blomberg                  Inge
# 3395                Susanne              Hollmann              Domenica
# 3396                   Anup                 Kumar                  Rolf
#
#      last_author_lastName                                       abstractText  \
# 0                 Pafilis  High-performance computing (HPC) systems have ...
# 1                  Sewald  Peptidotriazolamers are hybrid foldamers with ...
# 2                     NaN                                                NaN
# 3                     NaN                                                NaN
# 4                     NaN                                                NaN
# ...                   ...                                                ...
# 3392                  NaN  We describe the Data programme of the Dutch Te...
# 3393             Gabaldón  Biodiversity loss is now recognised as one of ...
# 3394             Jonassen  ELIXIR, the European life science infrastructu...
# 3395               D'Elia  Today, academic researchers benefit from the c...
# 3396             Backofen  Galaxy is a web-based open-source platform for...
#
#      printPublicationDate                  journal_title_df1  \
# 0              2021-08-01                        GigaScience
# 1              2019-01-01             Frontiers in chemistry
# 2                     NaN                                NaN
# 3              2020-11-01  Orphanet journal of rare diseases
# 4                     NaN                                NaN
# ...                   ...                                ...
# 3392                  NaN                                NaN
# 3393                  NaN                                NaN
# 3394                  NaN                                NaN
# 3395           2020-01-01                      F1000Research
# 3396                  NaN                                NaN
#
#                                             affiliation  \
# 0     Hellenic Centre for Marine Research, Institute...
# 1     Organic and Bioorganic Chemistry, Department o...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3392                                                NaN
# 3393                                                NaN
# 3394                                                NaN
# 3395  Faculty of Science, University of Potsdam, Pot...
# 3396                                                NaN
#
#                                                keywords  \
# 0     Biodiversity, Biotechnology, Aquaculture, High...
# 1     1, 2, Foldamer, Molecular Dynamic Simulations,...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3392                                                NaN
# 3393                                                NaN
# 3394                                                NaN
# 3395  Education, Open Access, Quality Management, St...
# 3396                                                NaN
#
#                                            meshHeadings  \
# 0     Marine Biology, Biotechnology, Aquaculture, Co...
# 1                                                   NaN
# 2                                                   NaN
# 3     Humans, Rare Diseases, Drug Approval, Orphan D...
# 4                                                   NaN
# ...                                                 ...
# 3392                                                NaN
# 3393                                                NaN
# 3394                                                NaN
# 3395  Trust, International Cooperation, Quality of L...
# 3396                                                NaN
#
#                                               mod_title         Year  \
# 0     0SAND1SINMARINEMOLECULARRESEARCH:AREGIONALHPCP...         2021
# 1     1,4-DISUBSTITUTED1H-1,2,3-TRIAZOLECONTAININGPE...         2019
# 2     10THANNIVERSARYOFTHEEUROPEANASSOCIATIONFORPRED...         2020
# 3     10THEUROPEANCONFERENCEONRAREDISEASES&ORPHANPRO...         2020
# 4     1H,13CAND15NASSIGNMENTOFTHEHUMANMITOCHONDRIALP...         2022
# ...                                                 ...          ...
# 3392  THEDUTCHTECHCENTREFORLIFESCIENCES:ENABLINGDATA...  2015 | 2016
# 3393  THEELIXIRBIODIVERSITYCOMMUNITY:UNDERSTANDINGSH...  2024 | 2023
# 3394                    THEELIXIRCHANNELINF1000RESEARCH  2015 | 2016
# 3395  THENEEDFORSTANDARDISATIONINLIFESCIENCERESEARCH...         2020
# 3396  TRANSFORMER-BASEDTOOLRECOMMENDATIONSYSTEMINGALAXY  2023 | 2022
#
#                       journal_title_df2  \
# 0                           GigaScience
# 1                Frontiers in chemistry
# 2                      The EPMA journal
# 3     Orphanet journal of rare diseases
# 4          Biomolecular NMR assignments
# ...                                 ...
# 3392                                NaN
# 3393                                NaN
# 3394                                NaN
# 3395                      F1000Research
# 3396                 BMC bioinformatics
#
#                                                 doi_df2     Source  empty  \
# 0                           10.1093/gigascience/giab053        MED    NaN
# 1                                                   NaN        MED    NaN
# 2                            10.1007/s13167-020-00206-1        MED    NaN
# 3                            10.1186/s13023-020-01550-1        MED    NaN
# 4                            10.1007/s12104-022-10113-3        MED    NaN
# ...                                                 ...        ...    ...
# 3392                      10.12688/f1000research.6009.2        PPR    NaN
# 3393  10.12688/f1000research.133724.2 | 10.12688/f10...        PPR    NaN
# 3394                      10.12688/f1000research.7587.2        PPR    NaN
# 3395                     10.12688/f1000research.27500.1        MED    NaN
# 3396                          10.1101/2022.12.16.520746  PMC | PPR    NaN
#
#                             final_doi         first_author        last_author
# 0         10.1093/gigascience/giab053  Haris Zafeiropoulos  Evangelos Pafilis
# 1            10.3389/fchem.2019.00155     David C Schröder     Norbert Sewald
# 2          10.1007/s13167-020-00206-1                  NaN                NaN
# 3          10.1186/s13023-020-01550-1                  NaN                NaN
# 4          10.1007/s12104-022-10113-3                  NaN                NaN
# ...                               ...                  ...                ...
# 3392    10.12688/f1000research.6009.2         Lars Eijssen                NaN
# 3393  10.12688/f1000research.133724.2    Robert Waterhouse      Toni Gabaldón
# 3394    10.12688/f1000research.7587.2      Niklas Blomberg      Inge Jonassen
# 3395   10.12688/f1000research.27500.2     Susanne Hollmann    Domenica D'Elia
# 3396        10.1101/2022.12.16.520746           Anup Kumar      Rolf Backofen
#
# [3397 rows x 26 columns]

# %%
csv_to_json_format(input_table = articles_full_authors, output_json = 'ea_papers_author_data.json')

# %%
with open('ea_papers_author_data.json', 'r', encoding='utf-8') as jf:
    ea_papers_author_data = json.load(jf)

# %%
len(ea_papers_author_data) # matches the length of our previous filters
# Out:
# 3054

# %%
unique_fauthors = set(articles_full_authors['first_author'].unique())
unique_lauthors = set(articles_full_authors['last_author'].unique())

unique_authors = unique_fauthors.union(unique_lauthors)

# %%
print(f"Amount of unique first authors: {len(unique_fauthors)}")
print(f"Amount of unique last authors: {len(unique_lauthors)}")
print(f"Amount of unique authors: {len(unique_authors)}")
# Out:
# Amount of unique first authors: 2494
# Amount of unique last authors: 1997
# Amount of unique authors: 4289

# %%
unique_fauthors_fnames = set(articles_full_authors['first_author_firstName'].unique())
unique_lauthors_fnames = set(articles_full_authors['last_author_firstName'].unique())

unique_authors_fnames = unique_fauthors_fnames.union(unique_lauthors_fnames)

# %%
print(f"Amount of unique first authors' first names: {len(unique_fauthors_fnames)}")
print(f"Amount of unique last authors' first names: {len(unique_lauthors_fnames)}")
print(f"Amount of unique authors' first names: {len(unique_authors_fnames)}")
# Out:
# Amount of unique first authors' first names: 1822
# Amount of unique last authors' first names: 1457
# Amount of unique authors' first names: 2800

# %% [markdown]
# So we have gathered the information from papers that have all of the author information and made a first round of predictions.

# %% [markdown]
# Lastly, we include information of papers having at least info about the first or last author names:

# %%
articles_some_authors_names = pd.concat([articles_first_authors_all, articles_last_authors_all])
articles_some_authors_names = articles_some_authors_names.reset_index().drop(columns='index')

# %%
articles_some_authors_names
# Out:
#                                          Article Title source  \
# 0    3Rs toxicity testing and disease modeling proj...    MED
# 1    A benchmark of optimization solvers for genome...    MED
# 2    A recent origin of Orf3a from M protein across...    MED
# 3    A survey into the contribution of regional/nat...    PPR
# 4    A versatile and interoperable computational fr...    PPR
# ..                                                 ...    ...
# 106  htsget: a protocol for securely streaming geno...    MED
# 107  Mental health impact of the first wave of COVI...    MED
# 108  The Dutch Techcentre for Life Sciences: Enabli...    PPR
# 109  Capturing variation impact on molecular intera...    MED
# 110  No more business as usual: agile and effective...    PPR
#
#                         pmid                     pmcid  \
# 0                 32636731.0                PMC7332811
# 1                 38251879.0               PMC10878033
# 2                 33363705.0                PMC7749296
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ..                       ...                       ...
# 106               29931085.0                PMC6298043
# 107  34127211.0 | 33309957.0  PMC10068024 | PMC7726524
# 108                      NaN                       NaN
# 109               30602777.0                PMC6315030
# 110                      NaN                       NaN
#
#                                                doi_df1  \
# 0                              10.17179/excli2020-1463
# 1                            10.1128/msystems.00833-23
# 2                           10.1016/j.csbj.2020.11.047
# 3                      10.12688/f1000research.142165.1
# 4                            10.1101/2022.12.17.520865
# ..                                                 ...
# 106                      10.1093/bioinformatics/bty492
# 107  10.1016/j.rpsmen.2021.05.003 | 10.1016/j.rpsm....
# 108                      10.12688/f1000research.6009.2
# 109                         10.1038/s41467-018-07709-6
# 110                          10.1101/2020.02.21.959973
#
#                                                  title  \
# 0    3Rs toxicity testing and disease modeling proj...
# 1    A benchmark of optimization solvers for genome...
# 2    A recent origin of Orf3a from M protein across...
# 3    A survey into the contribution of regional/nat...
# 4    A versatile and interoperable computational fr...
# ..                                                 ...
# 106  htsget: a protocol for securely streaming geno...
# 107  Mental health impact of the first wave of COVI...
# 108  The Dutch Techcentre for Life Sciences: Enabli...
# 109  Capturing variation impact on molecular intera...
# 110  No more business as usual: agile and effective...
#
#                                           authorString first_author_firstName  \
# 0                                            Vinken M.                Mathieu
# 1                                           Machado D.                 Daniel
# 2                                         Ouzounis CA.             Christos A
# 3    Neves A, Willassen NP, Hjerde E, Cuesta I, Mar...                 Aitana
# 4    Niarakis A, Ostaszewski M, Mazein A, Kuperstei...                   Anna
# ..                                                 ...                    ...
# 106  Kelleher J, Lin M, Albach CH, Birney E, Davies...                 Jerome
# 107  Alonso J, Vilagut G, Mortier P, Ferrer M, Alay...                  Jordi
# 108  Eijssen L, Evelo CT, Kok R, Mons B, Hooft RW, ...                   Lars
# 109  IMEx Consortium Curators, Del-Toro N, Duesbury...                    NaN
# 110  Galaxy and HyPhy developments teams, Nekrutenk...                    NaN
#
#     first_author_lastName last_author_firstName last_author_lastName  \
# 0                  Vinken                   NaN                  NaN
# 1                 Machado                   NaN                  NaN
# 2                Ouzounis                   NaN                  NaN
# 3                   Neves                   NaN                  NaN
# 4                Niarakis                   NaN                  NaN
# ..                    ...                   ...                  ...
# 106              Kelleher                   NaN                  NaN
# 107                Alonso                   NaN                  NaN
# 108               Eijssen                   NaN                  NaN
# 109                   NaN                     P               Porras
# 110                   NaN                Sergei      Kosakovsky Pond
#
#                                           abstractText printPublicationDate  \
# 0    The 3Rs concept, calling for replacement, redu...           2020-01-01
# 1    Genome-scale metabolic modeling is a powerful ...           2024-02-01
# 2    The genome of SARS-CoV-2, the coronavirus resp...           2020-01-01
# 3    Background:  Regional/national SARS-CoV-2 geno...                  NaN
# 4    The COVID-19 Disease Map project is a large-sc...                  NaN
# ..                                                 ...                  ...
# 106  SummaryStandardized interfaces for efficiently...           2019-01-01
# 107  IntroductionHealthcare workers are vulnerable ...           2021-04-01
# 108  We describe the Data programme of the Dutch Te...                  NaN
# 109  The current wealth of genomic variation data i...           2019-01-01
# 110  The current state of much of the Wuhan pneumon...                  NaN
#
#                                      journal_title_df1  \
# 0                                        EXCLI journal
# 1                                             mSystems
# 2    Computational and structural biotechnology jou...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 106                   Bioinformatics (Oxford, England)
# 107              Revista de psiquiatria y salud mental
# 108                                                NaN
# 109                              Nature communications
# 110                                                NaN
#
#                                            affiliation  \
# 0    Department of In Vitro Toxicology and Dermato-...
# 1    Department of Biotechnology and Food Science, ...
# 2    Biological Computation & Process Laboratory (B...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 106  Big Data Institute, Li Ka Shing Centre for Hea...
# 107  Health Services Research Unit, IMIM-Institut H...
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
#
#                                               keywords  \
# 0    In vitro, In silico, Europe, 3Rs, Horizon 2020...
# 1    Metabolism, Genome-scale Modeling, Optimizatio...
# 2    Protein superfamily, Structure prediction, M p...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 106                                                NaN
# 107  Mental disorders, Disability, Healthcare Worke...
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
#
#                                           meshHeadings  \
# 0                                                  NaN
# 1    Humans, Ecosystem, Biochemical Phenomena, Geno...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 106  Computational Biology, Genomics, Genome, Softw...
# 107  Humans, Occupational Diseases, Prevalence, Cro...
# 108                                                NaN
# 109  Animals, Humans, Disease, Amino Acid Substitut...
# 110                                                NaN
#
#                                              mod_title         Year  \
# 0    3RSTOXICITYTESTINGANDDISEASEMODELINGPROJECTSIN...         2020
# 1    ABENCHMARKOFOPTIMIZATIONSOLVERSFORGENOME-SCALE...         2024
# 2    ARECENTORIGINOFORF3AFROMMPROTEINACROSSTHECORON...         2020
# 3    ASURVEYINTOTHECONTRIBUTIONOFREGIONAL/NATIONALP...         2023
# 4    AVERSATILEANDINTEROPERABLECOMPUTATIONALFRAMEWO...         2022
# ..                                                 ...          ...
# 106   HTSGET:APROTOCOLFORSECURELYSTREAMINGGENOMICDATA.         2019
# 107  MENTALHEALTHIMPACTOFTHEFIRSTWAVEOFCOVID-19PAND...  2021 | 2020
# 108  THEDUTCHTECHCENTREFORLIFESCIENCES:ENABLINGDATA...  2015 | 2016
# 109  CAPTURINGVARIATIONIMPACTONMOLECULARINTERACTION...         2019
# 110  NOMOREBUSINESSASUSUAL:AGILEANDEFFECTIVERESPONS...         2020
#
#                                      journal_title_df2  \
# 0                                        EXCLI journal
# 1                                             mSystems
# 2    Computational and structural biotechnology jou...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 106                   Bioinformatics (Oxford, England)
# 107              Revista de psiquiatria y salud mental
# 108                                                NaN
# 109                              Nature communications
# 110                                                NaN
#
#                                                doi_df2 Source  empty  \
# 0                              10.17179/excli2020-1463    MED    NaN
# 1                            10.1128/msystems.00833-23    MED    NaN
# 2                           10.1016/j.csbj.2020.11.047    MED    NaN
# 3                      10.12688/f1000research.142165.1    PPR    NaN
# 4                            10.1101/2022.12.17.520865    PPR    NaN
# ..                                                 ...    ...    ...
# 106                                                NaN    MED    NaN
# 107  10.1016/j.rpsmen.2021.05.003 | 10.1016/j.rpsm....    MED    NaN
# 108                      10.12688/f1000research.6009.2    PPR    NaN
# 109                         10.1038/s41467-018-07709-6    MED    NaN
# 110                          10.1101/2020.02.21.959973    PPR    NaN
#
#                                              final_doi         first_author  \
# 0                              10.17179/excli2020-1463       Mathieu Vinken
# 1                            10.1128/msystems.00833-23       Daniel Machado
# 2                           10.1016/j.csbj.2020.11.047  Christos A Ouzounis
# 3                      10.12688/f1000research.142165.1         Aitana Neves
# 4                            10.1101/2022.12.17.520865        Anna Niarakis
# ..                                                 ...                  ...
# 106                      10.1093/bioinformatics/bty492      Jerome Kelleher
# 107  10.1016/j.rpsmen.2021.05.003 | 10.1016/j.rpsm....         Jordi Alonso
# 108                      10.12688/f1000research.6009.2         Lars Eijssen
# 109                         10.1038/s41467-018-07709-6                  NaN
# 110                          10.1101/2020.02.21.959973                  NaN
#
#                 last_author
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 106                     NaN
# 107                     NaN
# 108                     NaN
# 109                P Porras
# 110  Sergei Kosakovsky Pond
#
# [111 rows x 26 columns]

# %%
csv_to_json_format(input_table = articles_some_authors_names, output_json = 'ea_papers_author_names_data.json')

# %%
with open('ea_papers_author_names_data.json', 'r', encoding='utf-8') as jf:
    ea_papers_author_names_data = json.load(jf)

# %%
len(ea_papers_author_names_data)
# Out:
# 111

# %% [markdown]
# genderTracker is run as:

# %% [markdown]
# ```bash
# python -m genderTracker -j <your_data.json> -od <output_folder> -v True
# ```

# %% [markdown]
# ## Analyzing PubMed corpus

# %%
papers_5k = pd.read_table('1312.csv')

# %%
# Convert to string and handle NaN values by replacing them with an empty string
papers_5k['authors'] = papers_5k['authors'].fillna('').astype(str)

# Apply the function to get first and last authors
papers_5k['first_author'] = papers_5k['authors'].apply(lambda x: x.split(',')[0] if x else '')
papers_5k['last_author'] = papers_5k['authors'].apply(lambda x: x.split(',')[-1].lstrip(' ') if x else '')

papers_5k = papers_5k[papers_5k['first_author']!='']
papers_5k = papers_5k[papers_5k['last_author']!='']

# %%
papers_5k
# Out:
#        category                             entry_id  \
# 0     subfields  https://openalex.org/subfields/1312
# 1     subfields  https://openalex.org/subfields/1312
# 2     subfields  https://openalex.org/subfields/1312
# 3     subfields  https://openalex.org/subfields/1312
# 4     subfields  https://openalex.org/subfields/1312
# ...         ...                                  ...
# 4995  subfields  https://openalex.org/subfields/1312
# 4996  subfields  https://openalex.org/subfields/1312
# 4997  subfields  https://openalex.org/subfields/1312
# 4998  subfields  https://openalex.org/subfields/1312
# 4999  subfields  https://openalex.org/subfields/1312
#
#                            openalex_id  \
# 0     https://openalex.org/W1775749144
# 1     https://openalex.org/W2100837269
# 2     https://openalex.org/W2128635872
# 3     https://openalex.org/W2107277218
# 4     https://openalex.org/W2144634347
# ...                                ...
# 4995  https://openalex.org/W2895451238
# 4996  https://openalex.org/W1849819493
# 4997  https://openalex.org/W1870980090
# 4998  https://openalex.org/W1999463736
# 4999  https://openalex.org/W2052326665
#
#                                                   doi  publication_year  \
# 0       https://doi.org/10.1016/s0021-9258(19)52451-6              1951
# 1                    https://doi.org/10.1038/227680a0              1970
# 2              https://doi.org/10.1006/abio.1976.9999              1976
# 3              https://doi.org/10.1006/meth.2001.1262              2001
# 4                                                 NaN              2001
# ...                                               ...               ...
# 4995  https://doi.org/10.1007/springerreference_39918              2011
# 4996    https://doi.org/10.1016/s1387-2656(05)11004-7              2005
# 4997     https://doi.org/10.1016/0022-510x(88)90132-3              1988
# 4998          https://doi.org/10.1073/pnas.1732912100              2003
# 4999       https://doi.org/10.1016/j.cell.2011.06.013              2011
#
#                                                 authors         first_author  \
# 0     OliverH. Lowry, NiraJ. Rosebrough, A. Farr, Ro...       OliverH. Lowry
# 1                                     Ulrich K. Laemmli    Ulrich K. Laemmli
# 2                                      Mark A. Bradford     Mark A. Bradford
# 3                Kenneth J. Livak, Thomas D. Schmittgen     Kenneth J. Livak
# 4      Joseph Sambrook, Elisabeth Fritsch, Tom Maniatis      Joseph Sambrook
# ...                                                 ...                  ...
# 4995                 Anita B. Roberts, Michael B. Sporn     Anita B. Roberts
# 4996   Michael V. Berridge, Patries M. Herst, An S. Tan  Michael V. Berridge
# 4997       Jan Lexell, Charles Taylor, Michael Sjöstróm           Jan Lexell
# 4998  Christos Sotiriou, Soek-Ying Neo, Lisa M. McSh...    Christos Sotiriou
# 4999  Jennifer C. Darnell, Sarah J. Van Driesche, Ch...  Jennifer C. Darnell
#
#                last_author first_author_firstName first_author_lastName  \
# 0           RoseJ. Randall                 Oliver                 Lowry
# 1        Ulrich K. Laemmli                 Ulrich               Laemmli
# 2         Mark A. Bradford                   Mark              Bradford
# 3     Thomas D. Schmittgen                Kenneth                 Livak
# 4             Tom Maniatis                 Joseph              Sambrook
# ...                    ...                    ...                   ...
# 4995      Michael B. Sporn                  Anita               Roberts
# 4996             An S. Tan                Michael              Berridge
# 4997      Michael Sjöstróm                    Jan                Lexell
# 4998         Edison T. Liu               Christos              Sotiriou
# 4999     Robert B. Darnell               Jennifer               Darnell
#
#      last_author_firstName last_author_lastName
# 0                     Rose              Randall
# 1                   Ulrich              Laemmli
# 2                     Mark             Bradford
# 3                   Thomas           Schmittgen
# 4                      Tom             Maniatis
# ...                    ...                  ...
# 4995               Michael                Sporn
# 4996                    An                  Tan
# 4997               Michael             Sjöstróm
# 4998                Edison                  Liu
# 4999                Robert              Darnell
#
# [4952 rows x 12 columns]

# %%
import re
def get_first_name(name):
    # Match the first part of the name, stopping before any uppercase letter followed by a dot
    match = re.match(r'([A-Za-z]+?)(?=[A-Z]\.)', name)
    return match.group(1) if match else name.split(' ')[0]

# %%
papers_5k['first_author_firstName'] = papers_5k['first_author'].apply(lambda x: get_first_name(x.split(' ')[0]))
papers_5k['first_author_lastName'] = papers_5k['first_author'].apply(lambda x: x.split(' ')[-1])
papers_5k['last_author_firstName'] = papers_5k['last_author'].apply(lambda x: get_first_name(x.split(' ')[0]))
papers_5k['last_author_lastName'] = papers_5k['last_author'].apply(lambda x: x.split(' ')[-1])

# %%
papers_5k.to_csv('1312_splitnames.csv', index=False)

# %%
papers_5k[papers_5k['openalex_id'].isna()].shape
# Out:
# (0, 12)

# %%
# Split the DataFrame into 4 parts
papers_5k_parts = np.array_split(papers_5k, 4)

# Access each part by indexing
part1 = papers_5k_parts[0]
part2 = papers_5k_parts[1]
part3 = papers_5k_parts[2]
part4 = papers_5k_parts[3]
# Out:
# /home/alexandre/miniconda3/envs/proteins/lib/python3.11/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
papers_5k
# Out:
#        category                             entry_id  \
# 0     subfields  https://openalex.org/subfields/1312
# 1     subfields  https://openalex.org/subfields/1312
# 2     subfields  https://openalex.org/subfields/1312
# 3     subfields  https://openalex.org/subfields/1312
# 4     subfields  https://openalex.org/subfields/1312
# ...         ...                                  ...
# 4995  subfields  https://openalex.org/subfields/1312
# 4996  subfields  https://openalex.org/subfields/1312
# 4997  subfields  https://openalex.org/subfields/1312
# 4998  subfields  https://openalex.org/subfields/1312
# 4999  subfields  https://openalex.org/subfields/1312
#
#                            openalex_id  \
# 0     https://openalex.org/W1775749144
# 1     https://openalex.org/W2100837269
# 2     https://openalex.org/W2128635872
# 3     https://openalex.org/W2107277218
# 4     https://openalex.org/W2144634347
# ...                                ...
# 4995  https://openalex.org/W2895451238
# 4996  https://openalex.org/W1849819493
# 4997  https://openalex.org/W1870980090
# 4998  https://openalex.org/W1999463736
# 4999  https://openalex.org/W2052326665
#
#                                                   doi  publication_year  \
# 0       https://doi.org/10.1016/s0021-9258(19)52451-6              1951
# 1                    https://doi.org/10.1038/227680a0              1970
# 2              https://doi.org/10.1006/abio.1976.9999              1976
# 3              https://doi.org/10.1006/meth.2001.1262              2001
# 4                                                 NaN              2001
# ...                                               ...               ...
# 4995  https://doi.org/10.1007/springerreference_39918              2011
# 4996    https://doi.org/10.1016/s1387-2656(05)11004-7              2005
# 4997     https://doi.org/10.1016/0022-510x(88)90132-3              1988
# 4998          https://doi.org/10.1073/pnas.1732912100              2003
# 4999       https://doi.org/10.1016/j.cell.2011.06.013              2011
#
#                                                 authors         first_author  \
# 0     OliverH. Lowry, NiraJ. Rosebrough, A. Farr, Ro...       OliverH. Lowry
# 1                                     Ulrich K. Laemmli    Ulrich K. Laemmli
# 2                                      Mark A. Bradford     Mark A. Bradford
# 3                Kenneth J. Livak, Thomas D. Schmittgen     Kenneth J. Livak
# 4      Joseph Sambrook, Elisabeth Fritsch, Tom Maniatis      Joseph Sambrook
# ...                                                 ...                  ...
# 4995                 Anita B. Roberts, Michael B. Sporn     Anita B. Roberts
# 4996   Michael V. Berridge, Patries M. Herst, An S. Tan  Michael V. Berridge
# 4997       Jan Lexell, Charles Taylor, Michael Sjöstróm           Jan Lexell
# 4998  Christos Sotiriou, Soek-Ying Neo, Lisa M. McSh...    Christos Sotiriou
# 4999  Jennifer C. Darnell, Sarah J. Van Driesche, Ch...  Jennifer C. Darnell
#
#                last_author first_author_firstName first_author_lastName  \
# 0           RoseJ. Randall                 Oliver                 Lowry
# 1        Ulrich K. Laemmli                 Ulrich               Laemmli
# 2         Mark A. Bradford                   Mark              Bradford
# 3     Thomas D. Schmittgen                Kenneth                 Livak
# 4             Tom Maniatis                 Joseph              Sambrook
# ...                    ...                    ...                   ...
# 4995      Michael B. Sporn                  Anita               Roberts
# 4996             An S. Tan                Michael              Berridge
# 4997      Michael Sjöstróm                    Jan                Lexell
# 4998         Edison T. Liu               Christos              Sotiriou
# 4999     Robert B. Darnell               Jennifer               Darnell
#
#      last_author_firstName last_author_lastName
# 0                     Rose              Randall
# 1                   Ulrich              Laemmli
# 2                     Mark             Bradford
# 3                   Thomas           Schmittgen
# 4                      Tom             Maniatis
# ...                    ...                  ...
# 4995               Michael                Sporn
# 4996                    An                  Tan
# 4997               Michael             Sjöstróm
# 4998                Edison                  Liu
# 4999                Robert              Darnell
#
# [4952 rows x 12 columns]

# %%
def csv_to_json_format(input_table, output_json: str) -> None:
    
    # Read the CSV file
    if type(input_table)==str: 
        df = pd.read_csv(input_table)
    elif isinstance(input_table, pd.DataFrame):
        df = input_table

    # Prepare the list for JSON data
    json_data = []

    # Iterate over each row to create the desired JSON structure
    for _, row in df.iterrows():
        # Extract relevant fields
        pmcid = row['openalex_id']
        first_author_first_name = row['first_author_firstName']
        first_author_last_name = row['first_author_lastName']
        last_author_first_name = row['last_author_firstName']
        last_author_last_name = row['last_author_lastName']

        # Construct the full names of authors
        authors = []
        if pd.notna(first_author_first_name) and pd.notna(first_author_last_name):
            first_author = f"{first_author_first_name} {first_author_last_name}"
            authors.append(first_author)
            authors.append(first_author_first_name)
            authors.append(first_author_last_name)
        else:
            authors.append("NaN")
            authors.append("NaN")
            authors.append("NaN")
            
        if pd.notna(last_author_first_name) and pd.notna(last_author_last_name):
            last_author = f"{last_author_first_name} {last_author_last_name}"
            authors.append(last_author)
            authors.append(last_author_first_name)
            authors.append(last_author_last_name)
        else:
            authors.append("NaN")
            authors.append("NaN")
            authors.append("NaN")

        # Format authors list as JSON string
        authors_json_str = json.dumps(authors)

        # Append the data in the required format
        json_data.append({
            "pmcid": pmcid,
            "authors": authors_json_str
        })

    # Write to output JSON file with proper encoding
    with open(output_json, 'w', encoding='utf-8') as json_file:
        json.dump(json_data, json_file, ensure_ascii=False, indent=4)

# %%
csv_to_json_format(input_table = part1, output_json = '1312_data1.json')
csv_to_json_format(input_table = part2, output_json = '1312_data2.json')
csv_to_json_format(input_table = part3, output_json = '1312_data3.json')
csv_to_json_format(input_table = part4, output_json = '1312_data4.json')

# %%
with open('data/1312_data.json', 'r', encoding='utf-8') as jf:
    papers_5k_data = json.load(jf)

# %%
papers_5k_data[:5]
# Out:
# [{'pmcid': 'https://openalex.org/W1775749144',
#   'authors': '["Oliver Lowry", "Oliver", "Lowry", "Rose Randall", "Rose", "Randall"]'},
#  {'pmcid': 'https://openalex.org/W2100837269',
#   'authors': '["Ulrich Laemmli", "Ulrich", "Laemmli", "Ulrich Laemmli", "Ulrich", "Laemmli"]'},
#  {'pmcid': 'https://openalex.org/W2128635872',
#   'authors': '["Mark Bradford", "Mark", "Bradford", "Mark Bradford", "Mark", "Bradford"]'},
#  {'pmcid': 'https://openalex.org/W2107277218',
#   'authors': '["Kenneth Livak", "Kenneth", "Livak", "Thomas Schmittgen", "Thomas", "Schmittgen"]'},
#  {'pmcid': 'https://openalex.org/W2144634347',
#   'authors': '["Joseph Sambrook", "Joseph", "Sambrook", "Tom Maniatis", "Tom", "Maniatis"]'}]
